# %%
#necessary imports
import random
import csv
import datetime
import time

# %%
print("This is a random dataset generator. It will produce a .csv")
# Out:
# This is a random dataset generator. It will produce a .csv

# %%
#Basic questions
rows=int(input("how many rows do you want?"))
columns=int(input("how many columns do you want?"))
# Out:
# how many rows do you want?3
# how many columns do you want?3

# %%
#ask different column names
cats=[]
num=[]
for i in range(columns):
    cat=input(f"what column do you want for column{i}")
    cats.append(cat)
    nmafrm=input(f"do you want {cat} to be numeric? Yes or n")
    if nmafrm == 'yes' or nmafrm=='Yes' or nmafrm=='y':
        num.append(i)
        print(f"cat{i} will be numeric")
    else:
        print(f"{cat} will not be numeric")
print(f"these are your columns: {cats}")
print(f"these are the numeric columns: {[cats[i] for i in num]}")
# Out:
# what column do you want for column0id
# do you want id to be numeric? Yes or ny
# cat0 will be numeric
# what column do you want for column1name
# do you want name to be numeric? Yes or nn
# name will not be numeric
# what column do you want for column2color
# do you want color to be numeric? Yes or nn
# color will not be numeric
# these are your columns: ['id', 'name', 'color']
# these are the numeric columns: ['id']

# %%
#numeric columns
fin=[[] for i in range(rows)]
listed=[]
print("will now start populating numeric columns")

max=int(input("what is the max possible number you want?"))
min=int(input("What is the min possible number you want?"))

for col in range(columns):
    li=input(f"do you want {col} to be a numeric list?")
    if li=='y' or li=='yes' or li=='Yes':
        listed.append(col)
for row in range(rows):
    for col in range(columns):
        if col in num:
            if col not in listed:
                v = random.randint(min, max)
                fin[row].append(v)
                print(f"{cats[col]}, row: {row}, value: {v}")
        else:
            fin[row].append("")
for row in fin[:2]:
    print(row)
# Out:
# will now start populating numeric columns
# what is the max possible number you want?1000
# What is the min possible number you want?1
# do you want 0 to be a numeric list?yes
# do you want 1 to be a numeric list?no
# do you want 2 to be a numeric list?no
# ['', '']
# ['', '']

# %%
#non-numeric
print("will now start populating non-numeric columns")
for row in range(rows):
    for col in range(columns):
        if col not in num:
            print("Active column:", col, "Active Row:", row)
            print("1: Random name")
            print("2: Random date")
            print("3: Random color")
            print("4: Random of your choice")
            choice=input("what is your choice?(1-4)")
            if choice =='1':
                names=['Liam', 'Olivia', 'Noah', 'Emma', 'Oliver', 'Ava', 'Elijah', 'Charlotte', 'William', 'Sophia', 'James', 'Amelia', 'Benjamin', 'Isabella', 'Lucas', 'Mia', 'Henry', 'Evelyn', 'Alexander', 'Harper','Mason', 'Camila', 'Michael', 'Gianna', 'Ethan', 'Abigail', 'Daniel', 'Luna', 'Jacob', 'Ella',
         'Logan', 'Elizabeth', 'Jackson', 'Sofia', 'Sebastian', 'Emily', 'Jack', 'Avery', 'Aiden', 'Mila',
         'Owen', 'Scarlett', 'Samuel', 'Eleanor', 'Matthew', 'Madison', 'Joseph', 'Layla', 'Levi', 'Penelope',
         'Mateo', 'Aria', 'David', 'Chloe', 'John', 'Grace', 'Wyatt', 'Ellie', 'Carter', 'Nora',
         'Julian', 'Hazel', 'Luke', 'Zoey', 'Grayson', 'Riley', 'Isaac', 'Victoria', 'Jayden', 'Lily',
         'Theodore', 'Aurora', 'Gabriel', 'Violet', 'Anthony', 'Nova', 'Dylan', 'Hannah', 'Leo', 'Emilia',
         'Lincoln', 'Zoe', 'Jaxon', 'Stella', 'Asher', 'Everly', 'Christopher', 'Isla', 'Josiah', 'Leah',
         'Andrew', 'Lillian', 'Thomas', 'Addison', 'Joshua', 'Willow', 'Ezra', 'Lucy', 'Hudson', 'Paisley',
         'Charles', 'Natalie', 'Caleb', 'Naomi', 'Isaiah', 'Eliana', 'Ryan', 'Brooklyn', 'Nathan', 'Elena',
         'Adrian', 'Aubrey', 'Christian', 'Claire', 'Maverick', 'Ivy', 'Colton', 'Kinsley', 'Elias', 'Audrey',
         'Aaron', 'Maya', 'Eli', 'Genesis', 'Landon', 'Skylar', 'Jonathan', 'Bella', 'Nolan', 'Aaliyah',
         'Hunter', 'Madelyn', 'Cameron', 'Savannah', 'Connor', 'Anna', 'Santiago', 'Delilah', 'Jeremiah', 'Serenity',
         'Ezekiel', 'Caroline', 'Angel', 'Kennedy', 'Roman', 'Valentina', 'Easton', 'Ruby', 'Miles', 'Sophie']
                fin[row][col]=random.choice(names)

            elif choice=='2':
                sd=datetime.datetime(1900,1,1)
                ed=datetime.datetime.now()
                rd=sd+datetime.timedelta(days=random.randint(0, (ed - sd).days))
                fin[row][col]=rd.strftime('%y-%m-%d')

            elif choice=='3':
                fin[row][col]=random.choice(['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Brown', 'Gray', 'Black', 'Navy'])
            elif choice=='4':
                choices=input("what are thy choices (seperate them with commas!):").split(',')
                fin[row][col]=random.choice(choices)
            else:
                print("invalid input so invalid will be placeholder")
                fin[row][col]=("invalid")
# Out:
# will now start populating non-numeric columns
# Active column: 1 Active Row: 0
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 0
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14720\3855070669.py in <module>
#      33
#      34             elif choice=='3':
# ---> 35                 fin[row][col]=random.choice(['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Brown', 'Gray', 'Black', 'Navy'])
#      36             elif choice=='4':
#      37                 choices=input("what are thy choices (seperate them with commas!):").split(',')
#
# IndexError: list assignment index out of range

# %% [markdown]
# # final check
# prev=int(input("how many rows do you want to preview?"))
# for row in fin[:prev]:
#     print(row)

# %%
#save

ultraconfirm=input("do you want to save this?")
if ultraconfirm=='yes' or ultraconfirm=='YES' or ultraconfirm=='Yes' or ultraconfirm=='y':
    finalpathname=input("what do you want to name it? Please include .csv")
    with open(finalpathname, 'w', newline='') as file:
        csv.writer(file).writerow(cats)
        csv.writer(file).writerows(fin)
    print("your data has been written as", finalpathname)
else:
    print("data not saved")
    time.sleep(1)

# %%
#necessary imports
import random
import csv
import datetime
import time

print("This is a random dataset generator. It will produce a .csv")

#Basic questions
rows=int(input("how many rows do you want?"))
columns=int(input("how many columns do you want?"))
#ask different column names
cats=[]
num=[]
fin=[[] for i in range(rows)]
listed=[]
for col in range(columns):
    cat=input(f"what column do you want for column{col}")
    cats.append(cat)
    nmafrm=input(f"do you want {cat} to be numeric? Yes or n")
    if nmafrm == 'yes' or nmafrm=='Yes' or nmafrm=='y':
        num.append(col)
        print(f"col{col} will be numeric")
        lit=input('do you want it to be a list or random?')
        if lit=='list':
            listed.append(col)
            
    else:
        print(f"{cat} will not be numeric")
print(f"these are your columns: {cats}")
print(f"these are the numeric columns: {[cats[col] for col in num]}")

#numeric columns


print("will now start populating numeric columns")

max=int(input("what is the max possible number you want?"))
min=int(input("What is the min possible number you want?"))

for row in range(rows):
    for col in range(columns):
        if col in num:
            if col in listed:
                fin[row].append(row+1)
            if col not in listed:
                v = random.randint(min, max)
                fin[row].append(v)
                print(f"{cats[col]}, row: {row}, value: {v}")
        else:
            fin[row].append("")
for row in fin[:2]:
    print(row)
    
#non-numeric
print("will now start populating non-numeric columns")
for row in range(rows):
    for col in range(columns):
        if col not in num:
            print("Active column:", col, "Active Row:", row)
            print("1: Random name")
            print("2: Random date")
            print("3: Random color")
            print("4: Random of your choice")
            choice=input("what is your choice?(1-4)")
            if choice =='1':
                names=['Liam', 'Olivia', 'Noah', 'Emma', 'Oliver', 'Ava', 'Elijah', 'Charlotte', 'William', 'Sophia', 'James', 'Amelia', 'Benjamin', 'Isabella', 'Lucas', 'Mia', 'Henry', 'Evelyn', 'Alexander', 'Harper','Mason', 'Camila', 'Michael', 'Gianna', 'Ethan', 'Abigail', 'Daniel', 'Luna', 'Jacob', 'Ella',
         'Logan', 'Elizabeth', 'Jackson', 'Sofia', 'Sebastian', 'Emily', 'Jack', 'Avery', 'Aiden', 'Mila',
         'Owen', 'Scarlett', 'Samuel', 'Eleanor', 'Matthew', 'Madison', 'Joseph', 'Layla', 'Levi', 'Penelope',
         'Mateo', 'Aria', 'David', 'Chloe', 'John', 'Grace', 'Wyatt', 'Ellie', 'Carter', 'Nora',
         'Julian', 'Hazel', 'Luke', 'Zoey', 'Grayson', 'Riley', 'Isaac', 'Victoria', 'Jayden', 'Lily',
         'Theodore', 'Aurora', 'Gabriel', 'Violet', 'Anthony', 'Nova', 'Dylan', 'Hannah', 'Leo', 'Emilia',
         'Lincoln', 'Zoe', 'Jaxon', 'Stella', 'Asher', 'Everly', 'Christopher', 'Isla', 'Josiah', 'Leah',
         'Andrew', 'Lillian', 'Thomas', 'Addison', 'Joshua', 'Willow', 'Ezra', 'Lucy', 'Hudson', 'Paisley',
         'Charles', 'Natalie', 'Caleb', 'Naomi', 'Isaiah', 'Eliana', 'Ryan', 'Brooklyn', 'Nathan', 'Elena',
         'Adrian', 'Aubrey', 'Christian', 'Claire', 'Maverick', 'Ivy', 'Colton', 'Kinsley', 'Elias', 'Audrey',
         'Aaron', 'Maya', 'Eli', 'Genesis', 'Landon', 'Skylar', 'Jonathan', 'Bella', 'Nolan', 'Aaliyah',
         'Hunter', 'Madelyn', 'Cameron', 'Savannah', 'Connor', 'Anna', 'Santiago', 'Delilah', 'Jeremiah', 'Serenity',
         'Ezekiel', 'Caroline', 'Angel', 'Kennedy', 'Roman', 'Valentina', 'Easton', 'Ruby', 'Miles', 'Sophie']
                fin[row][col]=random.choice(names)

            elif choice=='2':
                sd=datetime.datetime(1900,1,1)
                ed=datetime.datetime.now()
                rd=sd+datetime.timedelta(days=random.randint(0, (ed - sd).days))
                fin[row][col]=rd.strftime('%y-%m-%d')

            elif choice=='3':
                fin[row][col]=random.choice(['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Pink', 'Brown', 'Gray', 'Black', 'Navy'])
            elif choice=='4':
                choices=input("what are thy choices (seperate them with commas!):").split(',')
                fin[row][col]=random.choice(choices)
            else:
                print("invalid input so invalid will be placeholder")
                fin[row][col]="invalid"
#save

ultraconfirm=input("do you want to save this?")
if ultraconfirm=='yes' or ultraconfirm=='YES' or ultraconfirm=='Yes' or ultraconfirm=='y':
    finalpathname=input("what do you want to name it? Please include .csv")
    with open(finalpathname, 'w', newline='') as file:
        csv.writer(file).writerow(cats)
        csv.writer(file).writerows(fin)
    print("your data has been written as", finalpathname)
else:
    print("data not saved")
    time.sleep(1)
# Out:
# This is a random dataset generator. It will produce a .csv
# how many rows do you want?5
# how many columns do you want?5
# what column do you want for column0id
# do you want id to be numeric? Yes or nyes
# col0 will be numeric
# do you want it to be a list or random?list
# what column do you want for column1name
# do you want name to be numeric? Yes or nn
# name will not be numeric
# what column do you want for column2date
# do you want date to be numeric? Yes or nn
# date will not be numeric
# what column do you want for column3color
# do you want color to be numeric? Yes or nn
# color will not be numeric
# what column do you want for column4weight
# do you want weight to be numeric? Yes or nyes
# col4 will be numeric
# do you want it to be a list or random?r
# these are your columns: ['id', 'name', 'date', 'color', 'weight']
# these are the numeric columns: ['id', 'weight']
# will now start populating numeric columns
# what is the max possible number you want?1000
# What is the min possible number you want?1
# weight, row: 0, value: 158
# weight, row: 1, value: 587
# weight, row: 2, value: 292
# weight, row: 3, value: 922
# weight, row: 4, value: 299
# [1, '', '', '', 158]
# [2, '', '', '', 587]
# will now start populating non-numeric columns
# Active column: 1 Active Row: 0
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 0
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)2
# Active column: 3 Active Row: 0
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# Active column: 1 Active Row: 1
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 1
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)2
# Active column: 3 Active Row: 1
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# Active column: 1 Active Row: 2
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 2
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)2
# Active column: 3 Active Row: 2
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# Active column: 1 Active Row: 3
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 3
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)2
# Active column: 3 Active Row: 3
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# Active column: 1 Active Row: 4
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)1
# Active column: 2 Active Row: 4
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)2
# Active column: 3 Active Row: 4
# 1: Random name
# 2: Random date
# 3: Random color
# 4: Random of your choice
# what is your choice?(1-4)3
# do you want to save this?yes
# what do you want to name it? Please include .csvtest321.csv
# your data has been written as test321.csv
