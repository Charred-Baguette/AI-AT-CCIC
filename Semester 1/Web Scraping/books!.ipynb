# %%
import requests
from bs4 import BeautifulSoup
import random
from tqdm import tqdm
import pandas as pd
import re
import time

# %%
books={'Title':[],
      'Author':[],
       'Year Published':[],
       'Number of Logs':[]}

# %%
for i in range(1,11):
    time.sleep(1)
    url=f'https://openlibrary.org/trending/forever?page={i}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    trends = soup.find_all('div', class_="sri__main")
    for book in trends:
        Title = book.find('div', class_='resultTitle').text.strip()
        Author=book.find('span', class_='bookauthor').text.strip()
        detailed=book.find('span', class_='resultStats')
        pubdate=detailed.find('span', class_='resultDetails').text.strip()
        pubdate_cleaned = re.sub(r"(—|\d+ editions|\s{2,})", "", pubdate).strip()
        alldetails=book.find('div', class_='details')
        logged_text = None
        match = re.search(r'Logged (\d+) times', book.text)  # Search within the current book
        if match:
            logged_text = match.group(0) 
        print(Title)
        print(Author)
        print(pubdate_cleaned)
        print(logged_text)
        books['Title'].append(Title)
        books['Author'].append(Author)
        books['Year Published'].append(pubdate_cleaned)
        books['Number of Logs'].append(logged_text)
# Out:
# Atomic Habits
# by James Clear
# First published in 2016
# Logged 41181 times
# It Ends With Us
# by Colleen Hoover
# First published in 2012
# Logged 40568 times
# The 48 Laws of Power
# by Robert Greene and Joost Elffers
# First published in 1998
# Logged 34986 times
# The Subtle Art of Not Giving a F*ck
# by Mark Manson
# First published in 2016
# Logged 30182 times
# Um casamento arranjado
# by Zana Kheiron
# First published in 2019
# Logged 23272 times
# Rich Dad, Poor Dad
# by Robert T. Kiyosaki and Sharon L. Lechter
# First published in 1990
# Logged 23002 times
# Harry Potter and the Philosopher's Stone
# by J. K. Rowling
# First published in 1997
# Logged 15987 times
# It Starts with Us
# by Colleen Hoover
# First published in 2022
# Logged 15547 times
# Control Your Mind and Master Your Feelings
# by Eric Robertson - undifferentiated
# First published in 2019
# Logged 15511 times
# Think and Grow Rich
# by Napoleon Hill
# First published in 1937
# Logged 11716 times
# Latidos Que No Dije
# by Roos
# First published in 2022
# Logged 9778 times
# How to Win Friends and Influence People
# by Dale Carnegie
# First published in 1913
# Logged 9226 times
# Twisted Love
# by Ana Huang
# First published in 2021
# Logged 8840 times
# A Game of Thrones
# by George R. R. Martin
# First published in 1996
# Logged 8596 times
# It
# by Stephen King
# First published in 1925
# Logged 7917 times
# A Court of Mist and Fury
# by Sarah J. Maas
# First published in 2014
# Logged 7827 times
# The Psychology of Money
# by Morgan Housel
# First published in 2020
# Logged 7760 times
# The Love Hypothesis
# by Ali Hazelwood
# First published in 2021
# Logged 7097 times
# Shatter Me
# by Tahereh Mafi
# First published in 2011
# Logged 6849 times
# Haunting Adeline
# by H. D. Carlton
# First published in 2021
# Logged 6823 times
# Ugly Love
# by Colleen Hoover
# First published in 2014
# Logged 6200 times
# Icebreaker
# by Hannah Grace
# First published in 2020
# Logged 5624 times
# The Power of Your Subconscious Mind
# by Joseph Murphy
# First published in 1963
# Logged 5576 times
# I Don't Love You Anymore
# by Rithvik Singh
# First published in 2020
# Logged 5467 times
# The Alchemist
# by Paulo Coelho
# First published in 1988
# Logged 5437 times
# Nineteen Eighty-Four
# by George Orwell
# First published in 1949
# Logged 5208 times
# Fifty Shades of Grey
# by E. L. James
# First published in 2000
# Logged 5060 times
# Harry Potter and the Chamber of Secrets
# by J. K. Rowling
# First published in 1998
# Logged 4978 times
# The Hunger Games
# by Suzanne Collins
# First published in 2008
# Logged 4906 times
# Harry Potter and the Deathly Hallows
# by J. K. Rowling
# First published in 2007
# Logged 4874 times
# The 7 Habits of Highly Effective People
# by Stephen R. Covey and Sean Covey
# First published in 1989
# Logged 4839 times
# Pride and Prejudice
# by Jane Austen
# First published in 1813
# Logged 4725 times
# Diary of a Wimpy Kid
# by Jeff Kinney
# First published in 1900
# Logged 4652 times
# The Lightning Thief
# by Rick Riordan
# First published in 2005
# Logged 4651 times
# Twilight
# by Stephenie Meyer
# First published in 2005
# Logged 4492 times
# Twisted Lies
# by Ana Huang and Mariona Gastó Jiménez
# First published in 2022
# Logged 4406 times
# To Kill a Mockingbird
# by Harper Lee
# First published in 1960
# Logged 4398 times
# The Cruel Prince
# by Holly Black, Caitlin Kelly, LitJoy Crate, and Holly Black
# First published in 2018
# Logged 4326 times
# Harry Potter and the Prisoner of Azkaban
# by J. K. Rowling
# First published in 1999
# Logged 4255 times
# The Seven Husbands of Evelyn Hugo
# by Taylor Jenkins Reid
# First published in 2017
# Logged 4223 times
# Red, White & Royal Blue
# by Casey McQuiston
# First published in 2019
# Logged 4186 times
# Verity
# by Colleen Hoover
# First published in 2018
# Logged 4081 times
# Sapiens: A Brief History of Humankind
# by Yuval Noah Harari
# First published in 2011
# Logged 3978 times
# Twisted Games
# by Ana Huang
# First published in 2021
# Logged 3859 times
# Thinking, fast and slow
# by Daniel Kahneman
# First published in 2011
# Logged 3852 times
# The Hobbit
# by J.R.R. Tolkien
# First published in 1937
# Logged 3715 times
# I'm Glad My Mom Died
# by Jennette McCurdy
# First published in 2022
# Logged 3673 times
# Harry Potter and the Goblet of Fire
# by J. K. Rowling and Jim Kay
# First published in 1993
# Logged 3636 times
# The Art of Seduction
# by Robert Greene and Joost Elffers
# First published in 1901
# Logged 3558 times
# Can't Hurt Me: Master Your Mind and Defy the Odds
# by David Goggins
# First published in 2018
# Logged 3533 times
# The Power of Positive Thinking
# by Norman Vincent Peale
# First published in 1952
# Logged 3484 times
# The Silent Patient
# by Alex Michaelides
# First published in 2018
# Logged 3464 times
# A Good Girl's Guide to Murder
# by Holly Jackson
# First published in 2019
# Logged 3449 times
# Charlotte's Web
# by E. B. White
# First published in 1952
# Logged 3424 times
# The Art of War
# by Sun Tzu
# First published in 1900
# Logged 3421 times
# Read People Like a Book
# by Patrick King
# First published in 2020
# Logged 3416 times
# A Gentle Reminder
# by Bianca Sparacino
# First published in 2020
# Logged 3400 times
# The Fault in Our Stars
# by John Green
# First published in 2010
# Logged 3295 times
# Fahrenheit 451
# by Ray Bradbury
# First published in 1953
# Logged 3221 times
# 101 Essays That Will Change The Way You Think
# by Brianna Wiest
# First published in 2018
# Logged 3219 times
# Animal Farm
# by George Orwell
# First published in 1945
# Logged 3207 times
# Harry Potter and the Order of the Phoenix
# by J. K. Rowling
# First published in 2003
# Logged 3132 times
# Twisted Hate
# by Ana Huang
# First published in 2022
# Logged 3124 times
# The Laws of Human Nature
# by Robert Greene
# First published in 2018
# Logged 3080 times
# Dune
# by Frank Herbert
# First published in 1965
# Logged 3066 times
# November 9
# by Colleen Hoover
# First published in 2015
# Logged 3060 times
# The Summer I Turned Pretty
# by Jenny Han
# First published in 2000
# Logged 3053 times
# Heartstopper, Volume 1
# by Alice Oseman
# First published in 2018
# Logged 3026 times
# Wonder
# by R. J. Palacio
# First published in 2001
# Logged 3003 times
# The Song of Achilles
# by Madeline Miller and José Miguel Pallarés Sanmiguel
# First published in 2011
# Logged 2962 times
# No Longer Human
# by Osamu Dazai
# First published in 1948
# Logged 2876 times
# A Court of Thorns and Roses
# by Sarah J. Maas
# First published in 2015
# Logged 2832 times
# Harry Potter and the Half-Blood Prince
# by J. K. Rowling and Mary GrandPré
# First published in 2005
# Logged 2799 times
# Ikigai: The Japanese Secret to a Long and Happy Life
# by Héctor García and Francesc Miralles
# First published in 2017
# Logged 2754 times
# If he had been with me
# by Laura Nowlin
# First published in 2013
# Logged 2720 times
# King of Wrath
# by Ana Huang
# First published in 2022
# Logged 2702 times
# Where the Crawdads Sing
# by Delia Owens
# First published in 2018
# Logged 2696 times
# Deep Work: Rules for Focused Success in a Distracted World
# by Cal Newport
# First published in 2016
# Logged 2670 times
# The Hate U Give
# by Angie Thomas
# First published in 2017
# Logged 2667 times
# A Little Life
# by Hanya Yanagihara
# First published in 2015
# Logged 2645 times
# The Da Vinci Code
# by Dan Brown
# First published in 2003
# Logged 2633 times
# The Shining
# by Stephen King
# First published in 1977
# Logged 2620 times
# The Adventures of Sherlock Holmes [12 stories]
# by Arthur Conan Doyle
# First published in 1892
# Logged 2617 times
# Brave New World
# by Aldous Huxley
# First published in 1932
# Logged 2613 times
# Matilda
# by Roald Dahl
# First published in 1988
# Logged 2546 times
# Lord of Flies
# by William Golding
# First published in 1954
# Logged 2531 times
# Lolita
# by Vladimir Nabokov
# First published in 1955
# Logged 2530 times
# Reminders of Him
# by Colleen Hoover
# First published in 2022
# Logged 2523 times
# Girl In pieces: a Novel
# by Kathleen Glasgow
# First published in 2016
# Logged 2505 times
# Le petit prince
# by Antoine de Saint-Exupéry
# First published in 1943
# Logged 2452 times
# Charlie and the Chocolate Factory
# by Roald Dahl
# First published in 1964
# Logged 2390 times
# How to Talk to Anyone
# by Leil Lowndes and LEILA
# First published in 1999
# Logged 2388 times
# 12 Rules for Life: An Antidote to Chaos
# by Jordan B. Peterson
# First published in 2015
# Logged 2336 times
# Coraline
# by Neil Gaiman and Neil Gaiman
# First published in 2002
# Logged 2321 times
# The Handmaid's Tale
# by Margaret Atwood
# First published in 1985
# Logged 2317 times
# The Great Gatsby
# by F. Scott Fitzgerald
# First published in 1920
# Logged 2287 times
# The Power of Now: A Guide to Spiritual Enlightenment
# by Eckhart Tolle
# First published in 1997
# Logged 2275 times
# Girl in Pieces
# by Kathleen Glasgow
# First published in 2016
# Logged 2264 times
# The Giver
# by Lois Lowry
# First published in 1993
# Logged 2256 times
# Misery
# by Stephen King
# First published in 1978
# Logged 2256 times
# Hunting Adeline
# by H. D. Carlton
# First published in 2022
# Logged 2248 times
# Pet Sematary
# by Stephen King
# First published in 1925
# Logged 2219 times
# Romeo and Juliet
# by William Shakespeare
# First published in 1597
# Logged 2202 times
# Little Women
# by Louisa May Alcott
# First published in 1848
# Logged 2196 times
# The Catcher in the Rye
# by J. D. Salinger
# First published in 1900
# Logged 2187 times
# The Summer I Turned Pretty Trilogy
# by Jenny Han
# First published in 2009
# Logged 2177 times
# The Book Thief
# by Markus Zusak
# First published in 1998
# Logged 2143 times
# Carrie
# by Stephen King
# First published in 1974
# Logged 2132 times
# Wuthering Heights
# by Emily Brontë
# First published in 1847
# Logged 2132 times
# They Both Die at the End
# by Adam Silvera
# First published in 2017
# Logged 2114 times
# A Brief History of Time
# by Stephen Hawking
# First published in 1988
# Logged 2111 times
# The Perks of Being a Wallflower
# by Stephen Chbosky and Stephen Chbosky
# First published in 1999
# Logged 2103 times
# The Spanish Love Deception
# by Elena Armas
# First published in 2021
# Logged 2071 times
# Six of Crows
# by Leigh Bardugo
# First published in 2001
# Logged 2054 times
# Milk and Honey
# by Rupi Kaur
# First published in 2014
# Logged 2033 times
# Punk 57
# by Penelope Douglas
# First published in 2016
# Logged 2029 times
# Don't Believe Everything You Think
# by Joseph Nguyen
# First published in 2022
# Logged 1948 times
# Dog Days
# by Jeff Kinney
# First published in 2004
# Logged 1913 times
# The Eyes of Darkness
# by Dean Koontz
# First published in 1981
# Logged 1901 times
# The Kite Runner
# by Khaled Hosseini
# First published in 2003
# Logged 1893 times
# The Lord of the Rings
# by J.R.R. Tolkien
# First published in 1954
# Logged 1890 times
# Hatchet
# by Gary Paulsen
# First published in 1986
# Logged 1864 times
# Better Than the Movies
# by Lynn Painter
# First published in 2021
# Logged 1844 times
# The Old Man and the Sea
# by Ernest Hemingway
# First published in 1952
# Logged 1835 times
# The Lost Hero
# by Rick Riordan and Rick Riordan
# First published in 2010
# Logged 1799 times
# Het Achterhuis
# by Anne Frank
# First published in 1944
# Logged 1796 times
# Holes
# by Louis Sachar
# First published in 1988
# Logged 1794 times
# The fellowship of the ring
# by J.R.R. Tolkien
# First published in 1954
# Logged 1785 times
# The Maze Runner
# by James Dashner
# First published in 2009
# Logged 1783 times
# The Hitch Hiker's Guide to the Galaxy
# by Douglas Adams
# First published in 1979
# Logged 1769 times
# Die Verwandlung
# by Franz Kafka
# First published in 1915
# Logged 1765 times
# The Four Agreements
# by Don Miguel Ruiz
# First published in 1997
# Logged 1740 times
# Meditations
# by Marcus Aurelius
# First published in 1626
# Logged 1718 times
# Of Mice and Men
# by John Steinbeck
# First published in 1937
# Logged 1717 times
# Divergent
# by Veronica Roth
# First published in 2010
# Logged 1707 times
# ... Trotzdem Ja zum Leben sagen
# by Viktor E. Frankl
# First published in 1946
# Logged 1699 times
# American Psycho
# by Bret Easton Ellis and Mariano Antolín Rato
# First published in 1991
# Logged 1659 times
# You've Reached Sam
# by Dustin Thao
# First published in 2021
# Logged 1657 times
# The Secret
# by Rhonda Byrne
# First published in 2000
# Logged 1615 times
# Steve Jobs
# by Walter Isaacson
# First published in 2011
# Logged 1607 times
# Frankenstein or The Modern Prometheus
# by Mary Shelley
# First published in 1818
# Logged 1603 times
# The Color Purple
# by Alice Walker, Translator Lunine Pierre-Jerome, Alice Walker, and Alice Walker
# First published in 1976
# Logged 1583 times
# To All the Boys I've Loved Before
# by Jenny Han
# First published in 2014
# Logged 1582 times
# Wings of Fire
# by A. P. J. Abdul Kalam
# First published in 1999
# Logged 1571 times
# Fourth Wing
# by Rebecca Yarros
# First published in 2023
# Logged 1548 times
# The Outsiders
# by S. E. Hinton, Jim Fyfe, and Jodi Picoult
# First published in 1967
# Logged 1541 times
# The Secret History
# by Donna Tartt
# First published in 1992
# Logged 1539 times
# The Invisible Man
# by H. G. Wells
# First published in 1897
# Logged 1536 times
# Hujan
# by Tere Liye
# First published in 20181 edition
# Logged 1528 times
# L’étranger
# by Albert Camus
# First published in 1942
# Logged 1526 times
# I Fell in Love with Hope
# by Lancali
# First published in 2022
# Logged 1525 times
# Alice's Adventures in Wonderland
# by Lewis Carroll
# First published in 1865
# Logged 1521 times
# And Then There Were None
# by Agatha Christie
# First published in 1939
# Logged 1514 times
# Looking for Alaska
# by John Green
# First published in 2005
# Logged 1486 times
# Throne of Glass
# by Sarah J. Maas
# First published in 2012
# Logged 1486 times
# The Duke and I
# by Julia Quinn
# First published in 2000
# Logged 1473 times
# Shatter Me Complete Collection
# by Tahereh Mafi
# First published in 2011
# Logged 1463 times
# The Lion, the Witch and the Wardrobe
# by C.S. Lewis
# First published in 1950
# Logged 1460 times
# Elon Musk
# by Ashlee Vance and Francisco López Martín
# First published in 2013
# Logged 1456 times
# Bible
# by Bible
# First published in 1200
# Logged 1455 times
# Ender's Game
# by Orson Scott Card
# First published in 1985
# Logged 1453 times
# The Intelligent Investor
# by Graham, Benjamin;Zweig, Jason
# First published in 20031 edition
# Logged 1449 times
# Why Men Love Bitches
# by Sherry Argov
# First published in 2022
# Logged 1443 times
# Tuesdays with Morrie
# by Mitch Albom
# First published in 1994
# Logged 1437 times
# The Sea of Monsters
# by Rick Riordan and Rick Riordan
# First published in 2005
# Logged 1436 times
# It Ends with Us, It Starts with Us: Ebook Collection
# by Colleen Hoover
# First published in 2022
# Logged 1430 times
# The Bell Jar
# by Sylvia Plath
# First published in 1963
# Logged 1427 times
# Ready Player One
# by Ernest Cline, Arnaud Regnauld, and Ernest Cline
# First published in 2008
# Logged 1422 times
# Workbook for the Mountain Is You
# by Smart Reads
# First published in 20221 edition
# Logged 1418 times
# The Richest Man in Babylon
# by George S. Clason
# First published in 1983
# Logged 1414 times
# Normal People
# by Sally Rooney
# First published in 2018
# Logged 1412 times
# Catching Fire
# by Suzanne Collins
# First published in 2009
# Logged 1409 times
# The Power of Habit: Why We Do What We Do in Life and Business
# by Charles Duhigg
# First published in 2012
# Logged 1407 times
# Good Girl, Bad Blood
# by Holly Jackson
# First published in 2020
# Logged 1404 times
# Foundation
# by Isaac Asimov
# First published in 1951
# Logged 1391 times
# Before the Coffee Gets Cold
# by Toshikazu Kawaguchi
# First published in 2019
# Logged 1386 times
# Dog Man
# by Dav Pilkey
# First published in 2015
# Logged 1383 times
# We Were Liars
# by E. Lockhart
# First published in 2014
# Logged 1381 times
# Dracula
# by Bram Stoker
# First published in 1897
# Logged 1380 times
# The BFG
# by Roald Dahl
# First published in 1980
# Logged 1376 times
# Men are From Mars, Women are From Venus
# by John Gray, John Gray, and John [Ph.D] Gray
# First published in 1992
# Logged 1362 times
# Harry Potter and the Cursed Child
# by Jack Thorne, John Tiffany, J. K. Rowling, Jack Thorne, and Jean-François Ménard
# First published in 2001
# Logged 1358 times
# Me Before You
# by Jojo Moyes and Various
# First published in 2012
# Logged 1357 times
# Moby Dick
# by Herman Melville
# First published in 1851
# Logged 1350 times
# The Secret Language of Birthdays: Personology Profiles for Each Day of the Year
# by Gary Goldschneider and Gary Goldschneider and Joost Elffers
# First published in 1992
# Logged 1347 times
# Hamlet
# by William Shakespeare
# First published in 1603
# Logged 1344 times
# A Thousand Splendid Suns
# by Khaled Hosseini
# First published in 2007
# Logged 1343 times
# Angels & Demons
# by Dan Brown
# First published in 2000
# Logged 1336 times
# The Curious Incident of the Dog in the Night-Time
# by Mark Haddon
# First published in 1950
# Logged 1329 times
# Beloved
# by Toni Morrison
# First published in 1987
# Logged 1316 times
# The Very Hungry Caterpillar
# by Eric Carle
# First published in 1929
# Logged 1314 times
# कामसूत्र
# by Mallanaga Vātsyāyana
# First published in 1883
# Logged 1306 times
# Things Fall Apart
# by Chinua Achebe
# First published in 1958
# Logged 1303 times
# Zero to One: Notes on Startups, or How to Build the Future
# by Peter A. Thiel and Blake Masters
# First published in 2001
# Logged 1303 times
# The Titan's Curse
# by Rick Riordan
# First published in 2007
# Logged 1300 times
# Cien años de soledad
# by Gabriel García Márquez
# First published in 1967
# Logged 1298 times
# A Wrinkle in Time
# by Madeleine L'Engle
# First published in 1962
# Logged 1296 times
# A child called "it"
# by David J. Pelzer
# First published in 1987
# Logged 1296 times
# I, Robot
# by Isaac Asimov
# First published in 1950
# Logged 1280 times

# %%
df = pd.DataFrame(books)
df['Year Published'] = df['Year Published'].str.replace(r'\D', '', regex=True).astype(int)
df['Number of Logs'] = df['Number of Logs'].str.replace(r'\D', '', regex=True).astype(int)

# %%
df.head()
# Out:
#                                  Title                              Author  \
# 0                        Atomic Habits                      by James Clear
# 1                      It Ends With Us                   by Colleen Hoover
# 2                 The 48 Laws of Power  by Robert Greene and Joost Elffers
# 3  The Subtle Art of Not Giving a F*ck                      by Mark Manson
# 4               Um casamento arranjado                     by Zana Kheiron
#
#    Year Published  Number of Logs
# 0            2016           41181
# 1            2012           40568
# 2            1998           34986
# 3            2016           30182
# 4            2019           23272

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           199 non-null    object
#  1   Author          199 non-null    object
#  2   Year Published  199 non-null    int32
#  3   Number of Logs  199 non-null    int32
# dtypes: int32(2), object(2)
# memory usage: 4.8+ KB

# %%
df.tail()
# Out:
#                     Title                     Author  Year Published  \
# 194     The Titan's Curse            by Rick Riordan            2007
# 195  Cien años de soledad  by Gabriel García Márquez            1967
# 196     A Wrinkle in Time       by Madeleine L'Engle            1962
# 197   A child called "it"         by David J. Pelzer            1987
# 198              I, Robot            by Isaac Asimov            1950
#
#      Number of Logs
# 194            1300
# 195            1298
# 196            1296
# 197            1296
# 198            1280

# %%
probability=(1/len(df))
print(f'Probability is: {probability}')
expectedlogs=0
for log in df['Number of Logs']:
    TMPexpLog=probability*log
    expectedlogs+=TMPexpLog
variance = (probability * (df['Number of Logs'] - expectedlogs) ** 2).sum()
StandardDeviation=variance ** 0.5
print(f'Variance: {variance}')
print(f'Expected value: {expectedlogs}')
print(f'Standard Deviation: {StandardDeviation}')
# Out:
# Probability is: 0.005025125628140704
# Variance: 32196316.943057
# Expected value: 3870.356783919598
# Standard Deviation: 5674.179847612957
