# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
api=input('api')

# %%
playingurl="https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"
playingheaders = {
    "accept": "application/json",
    "Authorization": f"Bearer {api}"
}

response = requests.get(playingurl, headers=playingheaders)
nowplaying_data = response.json() 
nowplaying_df = pd.json_normalize(nowplaying_data['results']) 
nowplaying_df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count
# 0  False         8.700        1060
# 1  False         7.300         718
# 2  False         6.000          78
# 3  False         5.700         645
# 4  False         7.203        1445

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api}"
}

response = requests.get(url, headers=headers)
popular = response.json() 
popular = pd.json_normalize(popular['results']) 
popular.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [878, 27]   945961
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 3  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg     [28, 35, 878]   533535
# 4  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
#
#   original_language        original_title  \
# 0                en        The Wild Robot
# 1                en        Alien: Romulus
# 2                en         The Substance
# 3                en  Deadpool & Wolverine
# 4                en                Azrael
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  While scavenging the deep ends of a derelict s...    6369.381
# 2  A fading celebrity decides to use a black mark...    4852.638
# 3  A listless Wade Wilson toils away in civilian ...    2958.871
# 4  In a world where no one speaks, a devout femal...    2309.545
#
#                         poster_path release_date                 title  video  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12        The Wild Robot  False
# 1  /b33nnKl1GSFbao4l3fZDDqsMx0F.jpg   2024-08-13        Alien: Romulus  False
# 2  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07         The Substance  False
# 3  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24  Deadpool & Wolverine  False
# 4  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                Azrael  False
#
#    vote_average  vote_count
# 0         8.696        1084
# 1         7.300        1719
# 2         7.300         726
# 3         7.716        4666
# 4         6.100          79

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api}"
}

response = requests.get(url, headers=headers)

response = requests.get(url, headers=headers)
toprated = response.json() 
toprated = pd.json_normalize(toprated['results']) 
toprated.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 2  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en  The Shawshank Redemption
# 2                en             The Godfather
# 3                en     The Godfather Part II
# 4                en          Schindler's List
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  Imprisoned in the 1940s for the double murder ...     248.751
# 2  Spanning the years 1945 to 1955, a chronicle o...     238.182
# 3  In the continuing saga of the Corleone crime f...     113.914
# 4  The true story of how businessman Oskar Schind...      88.453
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 2  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 3  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 4  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         8.707       26979
# 2  False         8.700       20492
# 3  False         8.600       12359
# 4  False         8.600       15767

# %%
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api}"
}

response = requests.get(url, headers=headers)
upcoming = response.json() 
upcoming = pd.json_normalize(upcoming['results']) 
upcoming.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg      [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en             The Substance
# 2                en                    Azrael
# 3                en               Terrifier 3
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  Five years after surviving Art the Clown's Hal...    1413.081
# 4  Hellboy and a rookie BPRD agent get stranded i...    1328.022
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07             The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 3  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09               Terrifier 3
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         7.300         722
# 2  False         6.000          78
# 3  False         7.000          94
# 4  False         4.982         142

# %%
df=pd.concat([upcoming, toprated, popular, nowplaying_df])

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg      [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en             The Substance
# 2                en                    Azrael
# 3                en               Terrifier 3
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  Five years after surviving Art the Clown's Hal...    1413.081
# 4  Hellboy and a rookie BPRD agent get stranded i...    1328.022
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07             The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 3  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09               Terrifier 3
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         7.300         722
# 2  False         6.000          78
# 3  False         7.000          94
# 4  False         4.982         142

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              57 non-null     bool
#  1   backdrop_path      57 non-null     object
#  2   genre_ids          57 non-null     object
#  3   id                 57 non-null     int64
#  4   original_language  57 non-null     object
#  5   original_title     57 non-null     object
#  6   overview           57 non-null     object
#  7   popularity         57 non-null     float64
#  8   poster_path        57 non-null     object
#  9   release_date       57 non-null     object
#  10  title              57 non-null     object
#  11  video              57 non-null     bool
#  12  vote_average       57 non-null     float64
#  13  vote_count         57 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 5.9+ KB

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg      [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en             The Substance
# 2                en                    Azrael
# 3                en               Terrifier 3
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  Five years after surviving Art the Clown's Hal...    1413.081
# 4  Hellboy and a rookie BPRD agent get stranded i...    1328.022
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07             The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 3  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09               Terrifier 3
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         7.300         722
# 2  False         6.000          78
# 3  False         7.000          94
# 4  False         4.982         142

# %%
df['revenue']=None
df['budget']=None
for index, row in df.iterrows():
    ID = row['id']
    url = f"https://api.themoviedb.org/3/movie/{ID}?language=en-US"

    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {api}"
}

    response = requests.get(url, headers=headers)
    details = response.json() 
    budget = details.get('budget') 
    df.at[index, 'budget'] = budget
    revenue = details.get('revenue') 
    df.at[index, 'revenue'] = revenue

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              57 non-null     bool
#  1   backdrop_path      57 non-null     object
#  2   genre_ids          57 non-null     object
#  3   id                 57 non-null     int64
#  4   original_language  57 non-null     object
#  5   original_title     57 non-null     object
#  6   overview           57 non-null     object
#  7   popularity         57 non-null     float64
#  8   poster_path        57 non-null     object
#  9   release_date       57 non-null     object
#  10  title              57 non-null     object
#  11  video              57 non-null     bool
#  12  vote_average       57 non-null     float64
#  13  vote_count         57 non-null     int64
#  14  revenue            57 non-null     object
#  15  budget             57 non-null     object
# dtypes: bool(2), float64(2), int64(2), object(10)
# memory usage: 8.8+ KB

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg      [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en             The Substance
# 2                en                    Azrael
# 3                en               Terrifier 3
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  Five years after surviving Art the Clown's Hal...    1413.081
# 4  Hellboy and a rookie BPRD agent get stranded i...    1328.022
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07             The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 3  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09               Terrifier 3
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count     revenue     budget
# 0  False         8.705        1069   196822000   78000000
# 1  False         7.300         722   348521150   80000000
# 2  False         6.000          78   245066411    6000000
# 3  False         7.000          94  1334640330  200000000
# 4  False         4.982         142   321365567   22000000

# %%
df['revenue'] = df['revenue'].astype(int)
df['budget'] = df['budget'].astype(int)
df['revenue'] = df['revenue'].replace(0, np.nan)
df['budget'] = df['budget'].replace(0, np.nan)

df['revenue']=np.log(df['revenue'])
df['budget']=np.log(df['budget'])

# %%
sns.regplot(data=df, x='revenue', y='budget')
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='budget'>

# %%
def linreg(df, x, y, n=150):
    m=0
    b=0
    bestres = float('inf')
    best_model = None
    opm, opb = None, None
    for i in range(n):
        resid=0
        df['residuals']=0
        model = None
        optimumresid = float('inf')
        print('starting scatter')
        
        print(f'starting predictions for epoch {i+1}')
        df['predicted']=m*df[x]+b
        
        print('starting residual testing for basic')
        df['residuals']=df[y]-df['predicted']
        resid = df['residuals'].pow(2).sum()

        mchange = -(2 / len(df)) * (df[x] * df['residuals']).sum()
        bchange = -(2 / len(df)) * df['residuals'].sum()
        
        
        m -= .0001 * mchange  
        b -= .0001 * bchange

        if resid < bestres:
            bestres = resid
            best_model = 'LSQ'
            opm, opb = m, b
        
        print(f'Epoch {i+1}: m={m}, b={b}, mchange={mchange}, bchange={bchange}, residual={resid}')
        
        
    print(f'Best model: {best_model} with residual squared: {bestres}')
    sns.scatterplot(data=df, x=x, y=y)
    

    plt.plot(df[x], df['predicted'], color='red', label='Regression Line')
    plt.show()
    print(opm, opb, bestres, f'Equation: y predicted = {opm}x+{opb}')
    return opm, opb, bestres, f'Equation: y predicted = {opm}x+{opb}'
    
#I know you said not to use other libraries, but I used seaborn and matplotlib only for visualization. It does not impact the calculations of the line in any way. It is only there to be useful to see what the line looks like.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
m, b, z, a = linreg(df, 'budget', 'revenue', 280)
# Out:
# starting scatter
# starting predictions for epoch 1
# starting residual testing for basic
# Epoch 1: m=0.03915627476353102, b=0.0022262913700157633, mchange=-391.5627476353102, bchange=-22.262913700157632, residual=12294.197272620011
# starting scatter
# starting predictions for epoch 2
# starting residual testing for basic
# Epoch 2: m=0.07690570153431547, b=0.0043730597859393825, mchange=-377.4942677078446, bchange=-21.46768415923619, residual=11433.190474274808
# starting scatter
# starting predictions for epoch 3
# starting residual testing for basic
# Epoch 3: m=0.11329882609029836, b=0.0064431623785390565, mchange=-363.9312455598288, bchange=-20.70102592599674, residual=10632.941408914652
# starting scatter
# starting predictions for epoch 4
# starting residual testing for basic
# Epoch 4: m=0.14838437818119743, b=0.008439353626485523, mchange=-350.85552090899057, bchange=-19.961912479464658, residual=9889.162651012062
# starting scatter
# starting predictions for epoch 5
# starting residual testing for basic
# Epoch 5: m=0.18220933677546655, b=0.010364289044476251, mchange=-338.2495859426912, bchange=-19.24935417990727, residual=9197.86932118061
# starting scatter
# starting predictions for epoch 6
# starting residual testing for basic
# Epoch 6: m=0.21481899296304102, b=0.012220528738851287, mchange=-326.09656187574484, bchange=-18.562396943750354, residual=8555.357736727121
# starting scatter
# starting predictions for epoch 7
# starting residual testing for basic
# Epoch 7: m=0.24625701059808874, b=0.014010540835461561, mchange=-314.3801763504772, bchange=-17.900120966102733, residual=7958.185568747397
# starting scatter
# starting predictions for epoch 8
# starting residual testing for basic
# Epoch 8: m=0.2765654847629651, b=0.015736704784379413, mchange=-303.08474164876367, bchange=-17.261639489178513, residual=7403.153399454757
# starting scatter
# starting predictions for epoch 9
# starting residual testing for basic
# Epoch 9: m=0.3057849981316525, b=0.01740131454587621, mchange=-292.19513368687393, bchange=-16.646097614967964, residual=6887.28758093276
# starting scatter
# starting predictions for epoch 10
# starting residual testing for basic
# Epoch 10: m=0.3339546753081523, b=0.019006581661932923, mchange=-281.69677176499795, bchange=-16.052671160567126, residual=6407.824303475843
# starting scatter
# starting predictions for epoch 11
# starting residual testing for basic
# Epoch 11: m=0.3611122352125861, b=0.02055463821739629, mchange=-271.5755990443382, bchange=-15.480565554633667, residual=5962.194788162225
# starting scatter
# starting predictions for epoch 12
# starting residual testing for basic
# Epoch 12: m=0.3872940415851491, b=0.022047539694745412, mchange=-261.81806372562966, bchange=-14.929014773491243, residual=5548.011524326573
# starting scatter
# starting predictions for epoch 13
# starting residual testing for basic
# Epoch 13: m=0.41253515167553745, b=0.023487267726291207, mchange=-252.41110090388372, bchange=-14.397280315457946, residual=5163.055478198104
# starting scatter
# starting predictions for epoch 14
# starting residual testing for basic
# Epoch 14: m=0.43686936318304376, b=0.024875732747493752, mchange=-243.34211507506296, bchange=-13.884650212025447, residual=4805.264204172978
# starting scatter
# starting predictions for epoch 15
# starting residual testing for basic
# Epoch 15: m=0.46032925951017, b=0.02621477655495024, mchange=-234.59896327126268, bchange=-13.390438074564894, residual=4472.720795025702
# starting scatter
# starting predictions for epoch 16
# starting residual testing for basic
# Epoch 16: m=0.4829462533903518, b=0.027506174772478555, mchange=-226.16993880181772, bchange=-12.913982175283138, residual=4163.643611859089
# starting scatter
# starting predictions for epoch 17
# starting residual testing for basic
# Epoch 17: m=0.5047506289482083, b=0.028751639228598424, mchange=-218.04375557856542, bchange=-12.454644561198684, residual=3876.376738769772
# starting scatter
# starting predictions for epoch 18
# starting residual testing for basic
# Epoch 18: m=0.525771582248636, b=0.029952820248593533, mchange=-210.2095330042766, bchange=-12.011810199951094, residual=3609.3811110890606
# starting scatter
# starting predictions for epoch 19
# starting residual testing for basic
# Epoch 19: m=0.546037260389038, b=0.031111308864223537, mchange=-202.65678140402068, bchange=-11.584886156300056, residual=3361.2262696676758
# starting scatter
# starting predictions for epoch 20
# starting residual testing for basic
# Epoch 20: m=0.5655747991870338, b=0.03222863894404469, mchange=-195.37538797995825, bchange=-11.173300798211526, residual=3130.582697026991
# starting scatter
# starting predictions for epoch 21
# starting residual testing for basic
# Epoch 21: m=0.5844103595141094, b=0.03330628924719148, mchange=-188.35560327075552, bchange=-10.7765030314679, residual=2916.214694316842
# starting scatter
# starting predictions for epoch 22
# starting residual testing for basic
# Epoch 22: m=0.6025691623238584, b=0.03434568540336922, mchange=-181.58802809749014, bchange=-10.393961561777417, residual=2716.9737609173826
# starting scatter
# starting predictions for epoch 23
# starting residual testing for basic
# Epoch 23: m=0.6200755224217153, b=0.0353482018217087, mchange=-175.06360097856935, bchange=-10.025164183394779, residual=2531.7924412154534
# starting scatter
# starting predictions for epoch 24
# starting residual testing for basic
# Epoch 24: m=0.6369528810213962, b=0.036315163531038745, mchange=-168.77358599681, bchange=-9.669617093300488, residual=2359.6786055888506
# starting scatter
# starting predictions for epoch 25
# starting residual testing for basic
# Epoch 25: m=0.6532238371316397, b=0.037247847954040805, mchange=-162.70956110243458, bchange=-9.326844230020592, residual=2199.710134958221
# starting scatter
# starting predictions for epoch 26
# starting residual testing for basic
# Epoch 26: m=0.6689101778152718, b=0.038147486617660965, mchange=-156.86340683632218, bchange=-8.996386636201613, residual=2051.029980428469
# starting scatter
# starting predictions for epoch 27
# starting residual testing for basic
# Epoch 27: m=0.6840329073611132, b=0.039015266802069674, mchange=-151.2272954584142, bchange=-8.677801844087071, residual=1912.841571551117
# starting scatter
# starting predictions for epoch 28
# starting residual testing for basic
# Epoch 28: m=0.6986122754077851, b=0.03985233313037696, mchange=-145.79368046671937, bchange=-8.370663283072894, residual=1784.4045486068837
# starting scatter
# starting predictions for epoch 29
# starting residual testing for basic
# Epoch 29: m=0.7126678040570735, b=0.0406597891012318, mchange=-140.55528649288397, bchange=-8.074559708548387, residual=1665.0307960436737
# starting scatter
# starting predictions for epoch 30
# starting residual testing for basic
# Epoch 30: m=0.7262183140131533, b=0.0414386985663576, mchange=-135.50509956079773, bchange=-7.789094651258025, residual=1554.0807558186825
# starting scatter
# starting predictions for epoch 31
# starting residual testing for basic
# Epoch 31: m=0.7392819497826725, b=0.04219008715500228, mchange=-130.63635769519234, bchange=-7.513885886446776, residual=1450.96000089292
# starting scatter
# starting predictions for epoch 32
# starting residual testing for basic
# Epoch 32: m=0.7518762039694383, b=0.0429149436472101, mchange=-125.94254186765798, bchange=-7.248564922078204, residual=1355.1160505202542
# starting scatter
# starting predictions for epoch 33
# starting residual testing for basic
# Epoch 33: m=0.7640179406962337, b=0.04361422129775411, mchange=-121.41736726795465, bchange=-6.9927765054400375, residual=1266.035410268525
# starting scatter
# starting predictions for epoch 34
# starting residual testing for basic
# Epoch 34: m=0.7757234181851269, b=0.04428883911250177, mchange=-117.05477488893149, bchange=-6.746178147476628, residual=1183.2408209143032
# starting scatter
# starting predictions for epoch 35
# starting residual testing for basic
# Epoch 35: m=0.7870083105265056, b=0.044939683078922904, mchange=-112.84892341378597, bchange=-6.508439664211359, residual=1106.2887014719258
# starting scatter
# starting predictions for epoch 36
# starting residual testing for basic
# Epoch 36: m=0.7978877286659857, b=0.04556760735238741, mchange=-108.79418139480136, bchange=-6.279242734645027, residual=1034.7667726575592
# starting scatter
# starting predictions for epoch 37
# starting residual testing for basic
# Epoch 37: m=0.8083762406372945, b=0.04617343539984123, mchange=-104.88511971308881, bchange=-6.058280474538196, residual=968.2918480556993
# starting scatter
# starting predictions for epoch 38
# starting residual testing for basic
# Epoch 38: m=0.8184878910682184, b=0.046757961102391915, mchange=-101.11650430923929, bchange=-5.845257025506884, residual=906.5077811540611
# starting scatter
# starting predictions for epoch 39
# starting residual testing for basic
# Epoch 39: m=0.8282362199857335, b=0.04732194981828005, mchange=-97.48328917515133, bchange=-5.639887158881368, residual=849.08355724784
# starting scatter
# starting predictions for epoch 40
# starting residual testing for basic
# Epoch 40: m=0.8376342809454985, b=0.04786613940765982, mchange=-93.9806095976508, bchange=-5.441895893797707, residual=795.7115199905095
# starting scatter
# starting predictions for epoch 41
# starting residual testing for basic
# Epoch 41: m=0.8466946585099843, b=0.04839124122056088, mchange=-90.60377564485695, bchange=-5.2510181290106095, residual=746.1057230897055
# starting scatter
# starting predictions for epoch 42
# starting residual testing for basic
# Epoch 42: m=0.8554294850986415, b=0.04889794104935435, mchange=-87.3482658865726, bchange=-5.0669982879347, residual=700.000398317207
# starting scatter
# starting predictions for epoch 43
# starting residual testing for basic
# Epoch 43: m=0.8638504572326705, b=0.04938690004699823, mchange=-84.20972134029054, bchange=-4.8895899764388435, residual=657.1485316252096
# starting scatter
# starting predictions for epoch 44
# starting residual testing for basic
# Epoch 44: m=0.8719688511961415, b=0.04985875561229177, mchange=-81.18393963471026, bchange=-4.71855565293539, residual=617.3205397402666
# starting scatter
# starting predictions for epoch 45
# starting residual testing for basic
# Epoch 45: m=0.8797955381344366, b=0.05031412224332403, mchange=-78.26686938294985, bchange=-4.5536663103225665, residual=580.3030401446038
# starting scatter
# starting predictions for epoch 46
# starting residual testing for basic
# Epoch 46: m=0.8873409986102285, b=0.05075359236025945, mchange=-75.45460475791974, bchange=-4.3947011693541835, residual=545.8977078548352
# starting scatter
# starting predictions for epoch 47
# starting residual testing for basic
# Epoch 47: m=0.894615336636488, b=0.051177737098562055, mchange=-72.7433802625943, bchange=-4.241447383026064, residual=513.9202128731486
# starting scatter
# starting predictions for epoch 48
# starting residual testing for basic
# Epoch 48: m=0.9016282932053058, b=0.05158710707372039, mchange=-70.12956568817881, bchange=-4.09369975158337, residual=484.19923261822237
# starting scatter
# starting predictions for epoch 49
# starting residual testing for basic
# Epoch 49: m=0.908389259330648, b=0.051982233118497125, mchange=-67.609661253422, bchange=-3.9512604477673015, residual=456.5755340448752
# starting scatter
# starting predictions for epoch 50
# starting residual testing for basic
# Epoch 50: m=0.9149072886225045, b=0.052363626993690446, mchange=-65.18029291856473, bchange=-3.8139387519331938, residual=430.9011205347826
# starting scatter
# starting predictions for epoch 51
# starting residual testing for basic
# Epoch 51: m=0.9211911094092696, b=0.05273178207335899, mchange=-62.83820786765109, bchange=-3.6815507966854173, residual=407.0384389876413
# starting scatter
# starting predictions for epoch 52
# starting residual testing for basic
# Epoch 52: m=0.927249136424585, b=0.0530871740054277, mchange=-60.58027015315286, bchange=-3.5539193206871302, residual=384.8596428646781
# starting scatter
# starting predictions for epoch 53
# starting residual testing for basic
# Epoch 53: m=0.9330894820742925, b=0.05343026134855922, mchange=-58.40345649707554, bchange=-3.4308734313152485, residual=364.2459072361735
# starting scatter
# starting predictions for epoch 54
# starting residual testing for basic
# Epoch 54: m=0.9387199672985849, b=0.05376148618614351, mchange=-56.304852242923765, bchange=-3.3122483758428363, residual=345.0867921632878
# starting scatter
# starting predictions for epoch 55
# starting residual testing for basic
# Epoch 55: m=0.9441481320438955, b=0.05408127471822776, mchange=-54.28164745310626, bchange=-3.19788532084255, residual=327.27965100343806
# starting scatter
# starting predictions for epoch 56
# starting residual testing for basic
# Epoch 56: m=0.949381245358551, b=0.054390037832179335, mchange=-52.331133146554365, bchange=-3.0876311395157465, residual=310.7290804691515
# starting scatter
# starting predictions for epoch 57
# starting residual testing for basic
# Epoch 57: m=0.9544263151257026, b=0.05468817165284559, mchange=-50.45069767151738, bchange=-2.981338206662537, residual=295.3464094940248
# starting scatter
# starting predictions for epoch 58
# starting residual testing for basic
# Epoch 58: m=0.9592900974465703, b=0.05497605807294741, mchange=-48.63782320867711, bchange=-2.8788642010182146, residual=281.04922416732813
# starting scatter
# starting predictions for epoch 59
# starting residual testing for basic
# Epoch 59: m=0.9639791056865603, b=0.055254065264416556, mchange=-46.89008239990001, bchange=-2.780071914691423, residual=267.76092619203706
# starting scatter
# starting predictions for epoch 60
# starting residual testing for basic
# Epoch 60: m=0.9684996191963716, b=0.05552254817136145, mchange=-45.20513509811293, bchange=-2.6848290694489148, residual=255.41032250068298
# starting scatter
# starting predictions for epoch 61
# starting residual testing for basic
# Epoch 61: m=0.9728576917197667, b=0.05578184898532154, mchange=-43.58072523395026, bchange=-2.593008139600874, residual=243.93124383033722
# starting scatter
# starting predictions for epoch 62
# starting residual testing for basic
# Epoch 62: m=0.9770591594992645, b=0.05603229760344651, mchange=-42.01467779497763, bchange=-2.5044861812497117, residual=233.26219021320526
# starting scatter
# starting predictions for epoch 63
# starting residual testing for basic
# Epoch 63: m=0.9811096490906093, b=0.05627421207021387, mchange=-40.50489591344747, bchange=-2.419144667673669, residual=223.34600148350603
# starting scatter
# starting predictions for epoch 64
# starting residual testing for basic
# Epoch 64: m=0.9850145848964779, b=0.05650789900327635, mchange=-39.04935805868615, bchange=-2.336869330624811, residual=214.12955103533375
# starting scatter
# starting predictions for epoch 65
# starting residual testing for basic
# Epoch 65: m=0.9887791964295133, b=0.056733654004009246, mchange=-37.646115330354704, bchange=-2.257550007328934, residual=205.5634611907816
# starting scatter
# starting predictions for epoch 66
# starting residual testing for basic
# Epoch 66: m=0.992408525314409, b=0.0569517620533075, mchange=-36.293288848958, bchange=-2.1810804929825234, residual=197.60183865337635
# starting scatter
# starting predictions for epoch 67
# starting residual testing for basic
# Epoch 67: m=0.9959074320384199, b=0.057162497893162426, mchange=-34.989067240108994, bchange=-2.1073583985492577, residual=190.20202862948506
# starting scatter
# starting predictions for epoch 68
# starting residual testing for basic
# Epoch 68: m=0.9992806024593378, b=0.05736612639452899, mchange=-33.73170420917902, bchange=-2.036285013665645, residual=183.32438630037169
# starting scatter
# starting predictions for epoch 69
# starting residual testing for basic
# Epoch 69: m=1.0025325540796466, b=0.057562902911976216, mchange=-32.51951620308706, bchange=-1.9677651744722462, residual=176.9320644205398
# starting scatter
# starting predictions for epoch 70
# starting residual testing for basic
# Epoch 70: m=1.0056676420952564, b=0.05775307362559557, mchange=-31.350880156097357, bchange=-1.9017071361935152, residual=170.99081590439351
# starting scatter
# starting predictions for epoch 71
# starting residual testing for basic
# Epoch 71: m=1.008690065226917, b=0.05793687587062513, mchange=-30.224231316606545, bchange=-1.8380224502956206, residual=165.46881034355312
# starting scatter
# starting predictions for epoch 72
# starting residual testing for basic
# Epoch 72: m=1.0116038713421183, b=0.058114538455230916, mchange=-29.138061152011115, bchange=-1.7766258460578128, residual=160.33646347179672
# starting scatter
# starting predictions for epoch 73
# starting residual testing for basic
# Epoch 73: m=1.0144129628750032, b=0.05828628196687079, mchange=-28.090915328849327, bchange=-1.7174351163987163, residual=155.56627866396363
# starting scatter
# starting predictions for epoch 74
# starting residual testing for basic
# Epoch 74: m=1.0171211020515545, b=0.05845231906765126, mchange=-27.081391765513892, bchange=-1.6603710078047318, residual=151.13269961963726
# starting scatter
# starting predictions for epoch 75
# starting residual testing for basic
# Epoch 75: m=1.019731915927047, b=0.05861285477907257, mchange=-26.10813875492657, bchange=-1.6053571142130825, residual=147.01197344233555
# starting scatter
# starting predictions for epoch 76
# starting residual testing for basic
# Epoch 76: m=1.0222489012425133, b=0.058768086756543325, mchange=-25.169853154663073, bchange=-1.552319774707524, residual=143.18202338064907
# starting scatter
# starting predictions for epoch 77
# starting residual testing for basic
# Epoch 77: m=1.0246754291067237, b=0.058918205554032294, mchange=-24.26527864210337, bchange=-1.5011879748896548, residual=139.62233054951545
# starting scatter
# starting predictions for epoch 78
# starting residual testing for basic
# Epoch 78: m=1.0270147495099509, b=0.059063394879211674, mchange=-23.393204032271544, bchange=-1.4518932517937966, residual=136.31382399794265
# starting scatter
# starting predictions for epoch 79
# starting residual testing for basic
# Epoch 79: m=1.0292699956755622, b=0.059203831839433486, mchange=-22.55246165611325, bchange=-1.4043696022181427, residual=133.23877853420424
# starting scatter
# starting predictions for epoch 80
# starting residual testing for basic
# Epoch 80: m=1.031444188255266, b=0.05933968717886843, mchange=-21.74192579703868, bchange=-1.3585533943493988, residual=130.38071976109364
# starting scatter
# starting predictions for epoch 81
# starting residual testing for basic
# Epoch 81: m=1.03354023937363, b=0.059471125507124696, mchange=-20.960511183638463, bchange=-1.314383282562637, residual=127.72433581245514
# starting scatter
# starting predictions for epoch 82
# starting residual testing for basic
# Epoch 82: m=1.0355609565272852, b=0.05959830551965292, mchange=-20.207171536553542, bchange=-1.2718001252822306, residual=125.25539531810604
# starting scatter
# starting predictions for epoch 83
# starting residual testing for basic
# Epoch 83: m=1.0375090463440406, b=0.059721380210232315, mchange=-19.480898167553406, bchange=-1.2307469057939058, residual=122.96067115764032
# starting scatter
# starting predictions for epoch 84
# starting residual testing for basic
# Epoch 84: m=1.0393871182069354, b=0.05984049707582251, mchange=-18.78071862894797, bchange=-1.1911686559019254, residual=120.82786959461691
# starting scatter
# starting predictions for epoch 85
# starting residual testing for basic
# Epoch 85: m=1.0411976877480877, b=0.05995579831405542, mchange=-18.10569541152324, bchange=-1.1530123823291116, residual=118.84556441145773
# starting scatter
# starting predictions for epoch 86
# starting residual testing for basic
# Epoch 86: m=1.0429431802170135, b=0.060067421013631536, mchange=-17.454924689258156, bchange=-1.1162269957612077, residual=117.00313569217815
# starting scatter
# starting predictions for epoch 87
# starting residual testing for basic
# Epoch 87: m=1.0446259337279278, b=0.0601754973378756, mchange=-16.827535109142186, bchange=-1.0807632424405786, residual=115.2907129249711
# starting scatter
# starting predictions for epoch 88
# starting residual testing for basic
# Epoch 88: m=1.046248202390375, b=0.060280154701697355, mchange=-16.222686624471834, bchange=-1.0465736382175914, residual=113.69912211980811
# starting scatter
# starting predictions for epoch 89
# starting residual testing for basic
# Epoch 89: m=1.0478121593273817, b=0.06038151594219451, mchange=-15.639569370066289, bchange=-1.0136124049714963, residual=112.21983665773861
# starting scatter
# starting predictions for epoch 90
# starting residual testing for basic
# Epoch 90: m=1.0493198995851711, b=0.06047969948312606, mchange=-15.07740257789345, bchange=-0.9818354093155294, residual=110.84493160855041
# starting scatter
# starting predictions for epoch 91
# starting residual testing for basic
# Epoch 91: m=1.0507734429383369, b=0.060574819493476484, mchange=-14.535433531656627, bchange=-0.9512001035042918, residual=109.56704127204961
# starting scatter
# starting predictions for epoch 92
# starting residual testing for basic
# Epoch 92: m=1.0521747365942309, b=0.060666986040322904, mchange=-14.012936558940888, bchange=-0.921665468464211, residual=108.37931971547691
# starting scatter
# starting predictions for epoch 93
# starting residual testing for basic
# Epoch 93: m=1.053525657800188, b=0.060756305236209986, mchange=-13.509212059570038, bchange=-0.8931919588708289, residual=107.27540409563991
# starting scatter
# starting predictions for epoch 94
# starting residual testing for basic
# Epoch 94: m=1.0548280163570751, b=0.060842879381229925, mchange=-13.023585568873154, bchange=-0.8657414501993741, residual=106.24938056925056
# starting scatter
# starting predictions for epoch 95
# starting residual testing for basic
# Epoch 95: m=1.0560835570425358, b=0.0609268070999977, mchange=-12.55540685460643, bchange=-0.8392771876777216, residual=105.29575260883303
# starting scatter
# starting predictions for epoch 96
# starting residual testing for basic
# Epoch 96: m=1.057293961947168, b=0.061008183473705034, mchange=-12.104049046321126, bchange=-0.8137637370733887, residual=104.40941155444781
# starting scatter
# starting predictions for epoch 97
# starting residual testing for basic
# Epoch 97: m=1.0584608527267692, b=0.0610871001674299, mchange=-11.668907796011972, bchange=-0.7891669372486745, residual=103.58560924346102
# starting scatter
# starting predictions for epoch 98
# starting residual testing for basic
# Epoch 98: m=1.0595857927736614, b=0.061163645552871945, mchange=-11.249400468922534, bchange=-0.765453854420445, residual=102.8199325717194
# starting scatter
# starting predictions for epoch 99
# starting residual testing for basic
# Epoch 99: m=1.0606702893100037, b=0.06123790482667827, mchange=-10.844965363422586, bchange=-0.7425927380632253, residual=102.10827984983887
# starting scatter
# starting predictions for epoch 100
# starting residual testing for basic
# Epoch 100: m=1.0617157954058951, b=0.061309960124517934, mchange=-10.45506095891485, bchange=-0.7205529783966744, residual=101.44683882793358
# starting scatter
# starting predictions for epoch 101
# starting residual testing for basic
# Epoch 101: m=1.0627237119249715, b=0.06137989063105798, mchange=-10.079165190763629, bchange=-0.6993050654004845, residual=100.83206627105179
# starting scatter
# starting predictions for epoch 102
# starting residual testing for basic
# Epoch 102: m=1.0636953894000987, b=0.06144777268598815, mchange=-9.716774751272512, bchange=-0.6788205493017224, residual=100.26066897588653
# starting scatter
# starting predictions for epoch 103
# starting residual testing for basic
# Epoch 103: m=1.0646321298416765, b=0.06151367988623634, mchange=-9.367404415778788, bchange=-0.6590720024819067, residual=99.72958612706378
# starting scatter
# starting predictions for epoch 104
# starting residual testing for basic
# Epoch 104: m=1.0655351884809723, b=0.0615776831845116, mchange=-9.030586392958426, bchange=-0.640032982752603, residual=99.23597289847208
# starting scatter
# starting predictions for epoch 105
# starting residual testing for basic
# Epoch 105: m=1.0664057754508198, b=0.06163985098430665, mchange=-8.705869698474936, bchange=-0.6216779979505465, residual=98.77718521178139
# starting scatter
# starting predictions for epoch 106
# starting residual testing for basic
# Epoch 106: m=1.067245057405933, b=0.06170024923148713, mchange=-8.392819551131147, bchange=-0.6039824718047528, residual=98.35076557049025
# starting scatter
# starting predictions for epoch 107
# starting residual testing for basic
# Epoch 107: m=1.0680541590850046, b=0.06175894150259013, mchange=-8.091016790716608, bchange=-0.5869227110299913, residual=97.95442989360727
# starting scatter
# starting predictions for epoch 108
# starting residual testing for basic
# Epoch 108: m=1.0688341648166817, b=0.06181598908995038, mchange=-7.800057316770849, bchange=-0.5704758736025366, residual=97.58605527842477
# starting scatter
# starting predictions for epoch 109
# starting residual testing for basic
# Epoch 109: m=1.0695861199714327, b=0.06187145108376795, mchange=-7.519551547510555, bchange=-0.5546199381756984, residual=97.24366862682484
# starting scatter
# starting predictions for epoch 110
# starting residual testing for basic
# Epoch 110: m=1.0703110323612524, b=0.061925384451227375, mchange=-7.249123898197455, bchange=-0.5393336745942517, residual=96.92543607418044
# starting scatter
# starting predictions for epoch 111
# starting residual testing for basic
# Epoch 111: m=1.071009873589077, b=0.06197784411277419, mchange=-6.988412278246546, bchange=-0.5245966154681717, residual=96.6296531642147
# starting scatter
# starting predictions for epoch 112
# starting residual testing for basic
# Epoch 112: m=1.0716835803497173, b=0.06202888301565097, mchange=-6.737067606403301, bchange=-0.5103890287677334, residual=96.354735717182
# starting scatter
# starting predictions for epoch 113
# starting residual testing for basic
# Epoch 113: m=1.0723330556840514, b=0.06207855220479128, mchange=-6.494753343339187, bchange=-0.49669189140318837, residual=96.09921134244314
# starting scatter
# starting predictions for epoch 114
# starting residual testing for basic
# Epoch 114: m=1.0729591701881553, b=0.06212690089116665, mchange=-6.261145041040608, bchange=-0.4834868637537016, residual=95.86171154996381
# starting scatter
# starting predictions for epoch 115
# starting residual testing for basic
# Epoch 115: m=1.0735627631789941, b=0.062173976517677795, mchange=-6.035929908387793, bchange=-0.4707562651114346, residual=95.6409644184726
# starting scatter
# starting predictions for epoch 116
# starting residual testing for basic
# Epoch 116: m=1.0741446438182283, b=0.06221982482267858, mchange=-5.81880639234063, bchange=-0.4584830500078208, residual=95.43578778099709
# starting scatter
# starting predictions for epoch 117
# starting residual testing for basic
# Epoch 117: m=1.0747055921956457, b=0.06226448990121763, mchange=-5.609483774173338, bchange=-0.4466507853904848, residual=95.24508289126862
# starting scatter
# starting predictions for epoch 118
# starting residual testing for basic
# Epoch 118: m=1.075246360373667, b=0.062308014264079635, mchange=-5.407681780214848, bchange=-0.4352436286201071, residual=95.06782853706355
# starting scatter
# starting predictions for epoch 119
# starting residual testing for basic
# Epoch 119: m=1.0757676733943244, b=0.062350438894705415, mchange=-5.213130206574581, bchange=-0.42424630625782, residual=94.90307556894193
# starting scatter
# starting predictions for epoch 120
# starting residual testing for basic
# Epoch 120: m=1.0762702302500595, b=0.06239180330406689, mchange=-5.025568557351752, bchange=-0.4136440936147696, residual=94.74994181506997
# starting scatter
# starting predictions for epoch 121
# starting residual testing for basic
# Epoch 121: m=1.0767547048196437, b=0.062432145583570534, mchange=-4.844745695842823, bchange=-0.4034227950364056, residual=94.6076073548844
# starting scatter
# starting predictions for epoch 122
# starting residual testing for basic
# Epoch 122: m=1.0772217467704719, b=0.06247150245606005, mchange=-4.670419508280788, bchange=-0.39356872489513944, residual=94.47531012627304
# starting scatter
# starting predictions for epoch 123
# starting residual testing for basic
# Epoch 123: m=1.0776719824284375, b=0.06250990932498664, mchange=-4.502356579655507, bchange=-0.38406868926589327, residual=94.3523418427407
# starting scatter
# starting predictions for epoch 124
# starting residual testing for basic
# Epoch 124: m=1.0781060156165556, b=0.06254740032181264, mchange=-4.340331881181445, bchange=-0.37490996826002293, residual=94.23804419868236
# starting scatter
# starting predictions for epoch 125
# starting residual testing for basic
# Epoch 125: m=1.078524428463455, b=0.06258400835171203, mchange=-4.184128468994333, bchange=-0.3660802989939651, residual=94.13180534243625
# starting scatter
# starting predictions for epoch 126
# starting residual testing for basic
# Epoch 126: m=1.0789277821828223, b=0.06261976513762901, mchange=-4.033537193672524, bchange=-0.3575678591697548, residual=94.03305659821783
# starting scatter
# starting predictions for epoch 127
# starting residual testing for basic
# Epoch 127: m=1.079316617824842, b=0.06265470126275356, mchange=-3.8883564201957714, bchange=-0.34936125124552553, residual=93.94126941937401
# starting scatter
# starting predictions for epoch 128
# starting residual testing for basic
# Epoch 128: m=1.0796914570006384, b=0.06268884621147103, mchange=-3.748391757964581, bchange=-0.34144948717469026, residual=93.85595255663512
# starting scatter
# starting predictions for epoch 129
# starting residual testing for basic
# Epoch 129: m=1.0800528025806904, b=0.06272222840884037, mchange=-3.613455800520107, bchange=-0.33382197369344935, residual=93.77664942618905
# starting scatter
# starting predictions for epoch 130
# starting residual testing for basic
# Epoch 130: m=1.0804011393681519, b=0.06275487525865406, mchange=-3.4833678746150447, bchange=-0.32646849813687084, residual=93.7029356634823
# starting scatter
# starting predictions for epoch 131
# starting residual testing for basic
# Epoch 131: m=1.0807369347479818, b=0.06278681318013052, mchange=-3.3579537983001964, bchange=-0.3193792147645878, residual=93.63441684963792
# starting scatter
# starting predictions for epoch 132
# starting residual testing for basic
# Epoch 132: m=1.0810606393127522, b=0.0628180676432883, mchange=-3.2370456477027996, bchange=-0.3125446315778005, residual=93.57072639831121
# starting scatter
# starting predictions for epoch 133
# starting residual testing for basic
# Epoch 133: m=1.0813726874659706, b=0.0628486632030493, mchange=-3.1204815321838293, bchange=-0.3059555976099068, residual=93.51152359166107
# starting scatter
# starting predictions for epoch 134
# starting residual testing for basic
# Epoch 134: m=1.081673498003728, b=0.06287862353211668, mchange=-3.008105377573622, bchange=-0.2996032906737652, residual=93.45649175491583
# starting scatter
# starting predictions for epoch 135
# starting residual testing for basic
# Epoch 135: m=1.0819634746754474, b=0.0629079714526716, mchange=-2.899766717195497, bchange=-0.2934792055491771, residual=93.40533655975135
# starting scatter
# starting predictions for epoch 136
# starting residual testing for basic
# Epoch 136: m=1.0822430067244873, b=0.06293672896693107, mchange=-2.7953204903978386, bchange=-0.2875751425947906, residual=93.35778444739331
# starting scatter
# starting predictions for epoch 137
# starting residual testing for basic
# Epoch 137: m=1.0825124694093196, b=0.06296491728660798, mchange=-2.6946268483237423, bchange=-0.2818831967691129, residual=93.313581162995
# starting scatter
# starting predictions for epoch 138
# starting residual testing for basic
# Epoch 138: m=1.0827722245059856, b=0.06299255686131258, mchange=-2.5975509666605054, bchange=-0.27639574704606074, residual=93.27249039343775
# starting scatter
# starting predictions for epoch 139
# starting residual testing for basic
# Epoch 139: m=1.0830226207924971, b=0.06301966740593365, mchange=-2.50396286511496, bchange=-0.2711054462106942, residual=93.2342925012563
# starting scatter
# starting predictions for epoch 140
# starting residual testing for basic
# Epoch 140: m=1.0832639945158347, b=0.06304626792703581, mchange=-2.413737233376522, bchange=-0.26600521102167224, residual=93.19878334790585
# starting scatter
# starting predictions for epoch 141
# starting residual testing for basic
# Epoch 141: m=1.0834966698421677, b=0.06307237674830851, mchange=-2.3267532633314754, bchange=-0.2610882127270641, residual=93.16577320006662
# starting scatter
# starting predictions for epoch 142
# starting residual testing for basic
# Epoch 142: m=1.0837209592908985, b=0.06309801153510061, mchange=-2.2428944873067818, bchange=-0.25634786792098196, residual=93.1350857131255
# starting scatter
# starting predictions for epoch 143
# starting residual testing for basic
# Epoch 143: m=1.083937164153111, b=0.06312318931807348, mchange=-2.1620486221249635, bchange=-0.2517778297286883, residual=93.10655698639009
# starting scatter
# starting predictions for epoch 144
# starting residual testing for basic
# Epoch 144: m=1.0841455748949873, b=0.06314792651600432, mchange=-2.0841074187619077, bchange=-0.24737197930841245, residual=93.08003468497157
# starting scatter
# starting predictions for epoch 145
# starting residual testing for basic
# Epoch 145: m=1.084346471546728, b=0.06317223895777016, mchange=-2.0089665174061486, bchange=-0.2431244176584887, residual=93.05537722363331
# starting scatter
# starting predictions for epoch 146
# starting residual testing for basic
# Epoch 146: m=1.0845401240775006, b=0.06319614190354204, mchange=-1.9365253077260567, bchange=-0.2390294577188738, residual=93.0324530082313
# starting scatter
# starting predictions for epoch 147
# starting residual testing for basic
# Epoch 147: m=1.0847267927569162, b=0.06321965006521768, mchange=-1.8666867941564855, bchange=-0.23508161675639364, residual=93.01113973068419
# starting scatter
# starting predictions for epoch 148
# starting residual testing for basic
# Epoch 148: m=1.0849067285035188, b=0.06324277762612004, mchange=-1.7993574660267257, bchange=-0.2312756090236467, residual=92.99132371369328
# starting scatter
# starting predictions for epoch 149
# starting residual testing for basic
# Epoch 149: m=1.085080173220754, b=0.06326553825998821, mchange=-1.7344471723534245, bchange=-0.22760633868159752, residual=92.97289930170305
# starting scatter
# starting predictions for epoch 150
# starting residual testing for basic
# Epoch 150: m=1.0852473601208672, b=0.06328794514928586, mchange=-1.671869001132502, bchange=-0.22406889297647978, residual=92.9557682948402
# starting scatter
# starting predictions for epoch 151
# starting residual testing for basic
# Epoch 151: m=1.085408514037164, b=0.06331001100285204, mchange=-1.6115391629679316, bchange=-0.22065853566184182, residual=92.93983942279607
# starting scatter
# starting predictions for epoch 152
# starting residual testing for basic
# Epoch 152: m=1.0855638517250523, b=0.06333174807291773, mchange=-1.5533768788816409, bchange=-0.21737070065693348, residual=92.92502785583542
# starting scatter
# starting predictions for epoch 153
# starting residual testing for basic
# Epoch 153: m=1.0857135821522677, b=0.06335316817151103, mchange=-1.4973042721536163, bchange=-0.2142009859329027, residual=92.9112547503119
# starting scatter
# starting predictions for epoch 154
# starting residual testing for basic
# Epoch 154: m=1.0858579067786727, b=0.0633742826862729, mchange=-1.4432462640490664, bchange=-0.21114514761870906, residual=92.89844682625353
# starting scatter
# starting predictions for epoch 155
# starting residual testing for basic
# Epoch 155: m=1.0859970198260016, b=0.06339510259570477, mchange=-1.3911304732904666, bchange=-0.20819909431872236, residual=92.8865359747576
# starting scatter
# starting predictions for epoch 156
# starting residual testing for basic
# Epoch 156: m=1.086131108537916, b=0.06341563848386823, mchange=-1.3408871191432665, bchange=-0.20535888163458013, residual=92.87545889308863
# starting scatter
# starting predictions for epoch 157
# starting residual testing for basic
# Epoch 157: m=1.086260353430714, b=0.06343590055455661, mchange=-1.2924489279818678, bchange=-0.20262070688377617, residual=92.86515674552737
# starting scatter
# starting predictions for epoch 158
# starting residual testing for basic
# Epoch 158: m=1.0863849285350353, b=0.06345589864495742, mchange=-1.245751043213458, bchange=-0.19998090400804813, residual=92.85557484815125
# starting scatter
# starting predictions for epoch 159
# starting residual testing for basic
# Epoch 159: m=1.086505001628879, b=0.06347564223882389, mchange=-1.20073093843789, bchange=-0.19743593866468873, residual=92.84666237585941
# starting scatter
# starting predictions for epoch 160
# starting residual testing for basic
# Epoch 160: m=1.0866207344622518, b=0.06349514047917332, mchange=-1.1573283337278146, bchange=-0.194982403494228, residual=92.83837209007083
# starting scatter
# starting predictions for epoch 161
# starting residual testing for basic
# Epoch 161: m=1.0867322829737434, b=0.06351440218052913, mchange=-1.1154851149163445, bchange=-0.19261701355812053, residual=92.83066008563908
# starting scatter
# starting predictions for epoch 162
# starting residual testing for basic
# Epoch 162: m=1.0868397974993218, b=0.06353343584072317, mchange=-1.0751452557847108, bchange=-0.19033660194035518, residual=92.82348555562427
# starting scatter
# starting predictions for epoch 163
# starting residual testing for basic
# Epoch 163: m=1.0869434229736263, b=0.06355224965227388, mchange=-1.0362547430458846, bchange=-0.1881381155071089, residual=92.81681057266641
# starting scatter
# starting predictions for epoch 164
# starting residual testing for basic
# Epoch 164: m=1.0870432991240286, b=0.06357085151335576, mchange=-0.9987615040230337, bchange=-0.1860186108187275, residual=92.8105998857846
# starting scatter
# starting predictions for epoch 165
# starting residual testing for basic
# Epoch 165: m=1.0871395606577212, b=0.06358924903837462, mchange=-0.962615336926577, bchange=-0.18397525018859365, residual=92.80482073151575
# starting scatter
# starting predictions for epoch 166
# starting residual testing for basic
# Epoch 166: m=1.087232337442085, b=0.06360744956816299, mchange=-0.9277678436361272, bchange=-0.18200529788358577, residual=92.79944265838105
# starting scatter
# starting predictions for epoch 167
# starting residual testing for basic
# Epoch 167: m=1.0873217546785747, b=0.06362546017980909, mchange=-0.894172364897759, bchange=-0.18010611646106417, residual=92.79443736373818
# starting scatter
# starting predictions for epoch 168
# starting residual testing for basic
# Epoch 168: m=1.0874079330703597, b=0.06364328769613284, mchange=-0.8617839178491921, bchange=-0.17827516323744405, residual=92.78977854214702
# starting scatter
# starting predictions for epoch 169
# starting residual testing for basic
# Epoch 169: m=1.0874909889839386, b=0.0636609386948212, mchange=-0.830559135789859, bchange=-0.17650998688366226, residual=92.78544174443518
# starting scatter
# starting predictions for epoch 170
# starting residual testing for basic
# Epoch 170: m=1.08757103460495, b=0.06367841951723549, mchange=-0.8004562101147349, bchange=-0.17480822414295105, residual=92.78140424670858
# starting scatter
# starting predictions for epoch 171
# starting residual testing for basic
# Epoch 171: m=1.0876481780883835, b=0.06369573627690214, mchange=-0.7714348343343311, bchange=-0.17316759666653542, residual=92.77764492860578
# starting scatter
# starting predictions for epoch 172
# starting residual testing for basic
# Epoch 172: m=1.0877225237033943, b=0.06371289486769845, mchange=-0.743456150106478, bchange=-0.17158590796304593, residual=92.77414416014321
# starting scatter
# starting predictions for epoch 173
# starting residual testing for basic
# Epoch 173: m=1.087794171972915, b=0.06372990097174419, mchange=-0.716482695206438, bchange=-0.17006104045749829, residual=92.77088369654491
# starting scatter
# starting predictions for epoch 174
# starting residual testing for basic
# Epoch 174: m=1.0878632198082516, b=0.06374676006700979, mchange=-0.6904783533668272, bchange=-0.16859095265596416, residual=92.76784658049476
# starting scatter
# starting predictions for epoch 175
# starting residual testing for basic
# Epoch 175: m=1.0879297606388436, b=0.063763477434651, mchange=-0.665408305919407, bchange=-0.1671736764120942, residual=92.76501705128514
# starting scatter
# starting predictions for epoch 176
# starting residual testing for basic
# Epoch 176: m=1.0879938845373611, b=0.06378005816608018, mchange=-0.6412389851744136, bchange=-0.16580731429185677, residual=92.76238046037727
# starting scatter
# starting predictions for epoch 177
# starting residual testing for basic
# Epoch 177: m=1.0880556783403086, b=0.06379650716978348, mchange=-0.6179380294751161, bchange=-0.16449003703296894, residual=92.7599231929201
# starting scatter
# starting predictions for epoch 178
# starting residual testing for basic
# Epoch 178: m=1.0881152257642952, b=0.06381282917789304, mchange=-0.5954742398669497, bchange=-0.163220081095593, residual=92.75763259480713
# starting scatter
# starting predictions for epoch 179
# starting residual testing for basic
# Epoch 179: m=1.0881726075181275, b=0.06382902875252314, mchange=-0.573817538323229, bchange=-0.16199574630102026, residual=92.75549690488057
# starting scatter
# starting predictions for epoch 180
# starting residual testing for basic
# Epoch 180: m=1.0882279014108747, b=0.06384511029187866, mchange=-0.5529389274724215, bchange=-0.16081539355522984, residual=92.75350519191952
# starting scatter
# starting predictions for epoch 181
# starting residual testing for basic
# Epoch 181: m=1.0882811824560519, b=0.06386107803614408, mchange=-0.5328104517715455, bchange=-0.15967744265419206, residual=92.75164729607476
# starting scatter
# starting predictions for epoch 182
# starting residual testing for basic
# Epoch 182: m=1.0883325229720595, b=0.06387693607316088, mchange=-0.5134051600753311, bchange=-0.15858037016806747, residual=92.74991377443638
# starting scatter
# starting predictions for epoch 183
# starting residual testing for basic
# Epoch 183: m=1.0883819926790144, b=0.06389268834390101, mchange=-0.4946970695496005, bchange=-0.15752270740138816, residual=92.74829585044199
# starting scatter
# starting predictions for epoch 184
# starting residual testing for basic
# Epoch 184: m=1.0884296587921025, b=0.06390833864774366, mchange=-0.47666113088159956, bchange=-0.15650303842655183, residual=92.74678536685536
# starting scatter
# starting predictions for epoch 185
# starting residual testing for basic
# Epoch 185: m=1.0884755861115765, b=0.06392389064756246, mchange=-0.45927319473977096, bchange=-0.1555199981879386, residual=92.74537474206332
# starting scatter
# starting predictions for epoch 186
# starting residual testing for basic
# Epoch 186: m=1.0885198371095204, b=0.06393934787462988, mchange=-0.4425099794391162, bchange=-0.1545722706741775, residual=92.74405692945626
# starting scatter
# starting predictions for epoch 187
# starting residual testing for basic
# Epoch 187: m=1.0885624720134972, b=0.06395471373334548, mchange=-0.426349039768011, bchange=-0.15365858715606226, residual=92.74282537967488
# starting scatter
# starting predictions for epoch 188
# starting residual testing for basic
# Epoch 188: m=1.0886035488871908, b=0.06396999150579426, mchange=-0.4107687369351468, bchange=-0.15277772448778434, residual=92.74167400552159
# starting scatter
# starting predictions for epoch 189
# starting residual testing for basic
# Epoch 189: m=1.0886431237081504, b=0.06398518435614117, mchange=-0.3957482095959565, bchange=-0.15192850346918388, residual=92.74059714934755
# starting scatter
# starting predictions for epoch 190
# starting residual testing for basic
# Epoch 190: m=1.0886812504427426, b=0.06400029533486785, mchange=-0.381267345920345, bchange=-0.15110978726686153, residual=92.73958955274117
# starting scatter
# starting predictions for epoch 191
# starting residual testing for basic
# Epoch 191: m=1.088717981118409, b=0.06401532738285705, mchange=-0.36730675666386575, bchange=-0.15032047989201003, residual=92.73864632835526
# starting scatter
# starting predictions for epoch 192
# starting residual testing for basic
# Epoch 192: m=1.0887533658933295, b=0.06403028333533034, mchange=-0.35384774920628326, bchange=-0.14955952473292847, residual=92.73776293372316
# starting scatter
# starting predictions for epoch 193
# starting residual testing for basic
# Epoch 193: m=1.0887874531235817, b=0.06404516592564437, mchange=-0.34087230252309675, bchange=-0.14882590314027205, residual=92.7369351469213
# starting scatter
# starting predictions for epoch 194
# starting residual testing for basic
# Epoch 194: m=1.0888202894278873, b=0.06405997778895067, mchange=-0.32836304305601816, bchange=-0.14811863306311696, residual=92.7361590439503
# starting scatter
# starting predictions for epoch 195
# starting residual testing for basic
# Epoch 195: m=1.0888519197500324, b=0.06407472146572407, mchange=-0.31630322145077855, bchange=-0.14743676773404987, residual=92.73543097771099
# starting scatter
# starting predictions for epoch 196
# starting residual testing for basic
# Epoch 196: m=1.0888823874190454, b=0.06408939940516421, mchange=-0.3046766901303155, bchange=-0.14677939440147955, residual=92.73474755846564
# starting scatter
# starting predictions for epoch 197
# starting residual testing for basic
# Epoch 197: m=1.0889117342072128, b=0.06410401396847497, mchange=-0.2934678816738677, bchange=-0.14614563310750164, residual=92.73410563567612
# starting scatter
# starting predictions for epoch 198
# starting residual testing for basic
# Epoch 198: m=1.0889400003860101, b=0.06411856743202594, mchange=-0.2826617879733089, bchange=-0.14553463550969747, residual=92.73350228112507
# starting scatter
# starting predictions for epoch 199
# starting residual testing for basic
# Epoch 199: m=1.088967224780024, b=0.06413306199040046, mchange=-0.27224394013719394, bchange=-0.1449455837451992, residual=92.73293477322744
# starting scatter
# starting predictions for epoch 200
# starting residual testing for basic
# Epoch 200: m=1.0889934448189358, b=0.06414749975933402, mchange=-0.26220038911823423, bchange=-0.1443776893356445, residual=92.73240058244951
# starting scatter
# starting predictions for epoch 201
# starting residual testing for basic
# Epoch 201: m=1.0890186965876394, b=0.06416188277854716, mchange=-0.25251768703593436, bchange=-0.14383019213142886, residual=92.73189735775624
# starting scatter
# starting predictions for epoch 202
# starting residual testing for basic
# Epoch 202: m=1.0890430148745565, b=0.06417621301447655, mchange=-0.24318286917029974, bchange=-0.14330235929388785, residual=92.73142291401558
# starting scatter
# starting predictions for epoch 203
# starting residual testing for basic
# Epoch 203: m=1.0890664332182167, b=0.06419049236290796, mchange=-0.23418343660283641, bchange=-0.14279348431406952, residual=92.73097522029138
# starting scatter
# starting predictions for epoch 204
# starting residual testing for basic
# Epoch 204: m=1.089088983952165, b=0.06420472265151463, mchange=-0.22550733948113394, bchange=-0.14230288606675487, residual=92.7305523889624
# starting scatter
# starting predictions for epoch 205
# starting residual testing for basic
# Epoch 205: m=1.0891106982482532, b=0.06421890564230447, mchange=-0.21714296088437254, bchange=-0.14182990789844582, residual=92.7301526656091
# starting scatter
# starting predictions for epoch 206
# starting residual testing for basic
# Epoch 206: m=1.0891316061583802, b=0.06423304303397928, mchange=-0.2090791012691193, bchange=-0.14137391674815403, residual=92.72977441961422
# starting scatter
# starting predictions for epoch 207
# starting residual testing for basic
# Epoch 207: m=1.0891517366547276, b=0.06424713646420925, mchange=-0.2013049634732066, bchange=-0.14093430229973677, residual=92.72941613542653
# starting scatter
# starting predictions for epoch 208
# starting residual testing for basic
# Epoch 208: m=1.0891711176685537, b=0.06426118751182572, mchange=-0.19381013825931814, bchange=-0.14051047616473858, residual=92.72907640444089
# starting scatter
# starting predictions for epoch 209
# starting residual testing for basic
# Epoch 209: m=1.0891897761275915, b=0.06427519769893518, mchange=-0.1865845903772462, bchange=-0.1401018710945523, residual=92.72875391745185
# starting scatter
# starting predictions for epoch 210
# starting residual testing for basic
# Epoch 210: m=1.0892077379921041, b=0.06428916849295727, mchange=-0.17961864512685757, bchange=-0.13970794022088265, residual=92.7284474576393
# starting scatter
# starting predictions for epoch 211
# starting residual testing for basic
# ...
# Epoch 212: m=1.089241671148566, b=0.06431699750970209, mchange=-0.1664285892151166, bchange=-0.1389620111245362, residual=92.72787817553356
# starting scatter
# starting predictions for epoch 213
# starting residual testing for basic
# Epoch 213: m=1.089257689830329, b=0.06433085841116283, mchange=-0.16018681762982287, bchange=-0.1386090146074175, residual=92.72761332512087
# starting scatter
# starting predictions for epoch 214
# starting residual testing for basic
# Epoch 214: m=1.0892731067606471, b=0.06434468528059896, mchange=-0.15416930318163846, bchange=-0.1382686943612879, residual=92.72736043477987
# starting scatter
# starting predictions for epoch 215
# starting residual testing for basic
# Epoch 215: m=1.0892879435595144, b=0.06435847934009378, mchange=-0.14836798867365106, bchange=-0.13794059494820288, residual=92.72711866055518
# starting scatter
# starting predictions for epoch 216
# starting residual testing for basic
# Epoch 216: m=1.0893022210701535, b=0.06437224176782312, mchange=-0.1427751063908127, bchange=-0.13762427729335638, residual=92.72688721804633
# starting scatter
# starting predictions for epoch 217
# starting residual testing for basic
# Epoch 217: m=1.0893159593869235, b=0.06438597369963284, mchange=-0.1373831676996496, bchange=-0.13731931809719722, residual=92.72666537820452
# starting scatter
# starting predictions for epoch 218
# starting residual testing for basic
# Epoch 218: m=1.0893291778822256, b=0.0643996762305597, mchange=-0.13218495302126848, bchange=-0.13702530926864784, residual=92.72645246342695
# starting scatter
# starting predictions for epoch 219
# starting residual testing for basic
# Epoch 219: m=1.089341895232442, b=0.06441335041629756, mchange=-0.12717350216447204, bchange=-0.13674185737867767, residual=92.72624784392667
# starting scatter
# starting predictions for epoch 220
# starting residual testing for basic
# Epoch 220: m=1.0893541294429427, b=0.06442699727461092, mchange=-0.12234210500666395, bchange=-0.1364685831335351, residual=92.72605093435801
# starting scatter
# starting predictions for epoch 221
# starting residual testing for basic
# Epoch 221: m=1.0893658978721936, b=0.0644406177866976, mchange=-0.11768429250891911, bchange=-0.13620512086686998, residual=92.725861190681
# starting scatter
# starting predictions for epoch 222
# starting residual testing for basic
# Epoch 222: m=1.0893772172549991, b=0.06445421289850262, mchange=-0.11319382805463338, bchange=-0.13595111805014437, residual=92.72567810724618
# starting scatter
# starting predictions for epoch 223
# starting residual testing for basic
# Epoch 223: m=1.089388103724909, b=0.06446778352198468, mchange=-0.1088646990985711, bchange=-0.13570623482059074, residual=92.72550121408584
# starting scatter
# starting predictions for epoch 224
# starting residual testing for basic
# Epoch 224: m=1.0893985728358206, b=0.0644813305363373, mchange=-0.10469110911683381, bchange=-0.13547014352617837, residual=92.72533007439566
# starting scatter
# starting predictions for epoch 225
# starting residual testing for basic
# Epoch 225: m=1.089408639582805, b=0.06449485478916599, mchange=-0.10066746984484291, bchange=-0.13524252828686126, residual=92.72516428219528
# starting scatter
# starting predictions for epoch 226
# starting residual testing for basic
# Epoch 226: m=1.0894183184221846, b=0.06450835709762315, mchange=-0.0967883937958234, bchange=-0.1350230845716804, residual=92.7250034601523
# starting scatter
# starting predictions for epoch 227
# starting residual testing for basic
# Epoch 227: m=1.0894276232908893, b=0.06452183824950225, mchange=-0.09304868704641758, bchange=-0.13481151879096648, residual=92.72484725756146
# starting scatter
# starting predictions for epoch 228
# starting residual testing for basic
# Epoch 228: m=1.0894365676251174, b=0.06453529900429257, mchange=-0.08944334228254004, bchange=-0.13460754790325255, residual=92.72469534846513
# starting scatter
# starting predictions for epoch 229
# starting residual testing for basic
# Epoch 229: m=1.089445164378327, b=0.0645487400941962, mchange=-0.08596753209497658, bchange=-0.13441089903630368, residual=92.7245474299073
# starting scatter
# starting predictions for epoch 230
# starting residual testing for basic
# Epoch 230: m=1.0894534260385784, b=0.06456216222510837, mchange=-0.08261660251534358, bchange=-0.13422130912173294, residual=92.72440322031034
# starting scatter
# starting predictions for epoch 231
# starting residual testing for basic
# Epoch 231: m=1.089461364645257, b=0.06457556607756265, mchange=-0.07938606678504662, bchange=-0.1340385245427885, residual=92.72426245796618
# starting scatter
# starting predictions for epoch 232
# starting residual testing for basic
# Epoch 232: m=1.0894689918051916, b=0.06458895230764213, mchange=-0.07627159934738077, bchange=-0.13386230079475275, residual=92.72412489963457
# starting scatter
# starting predictions for epoch 233
# starting residual testing for basic
# Epoch 233: m=1.0894763187081973, b=0.06460232154785789, mchange=-0.07326903005582558, bchange=-0.13369240215756356, residual=92.72399031924002
# starting scatter
# starting predictions for epoch 234
# starting residual testing for basic
# Epoch 234: m=1.0894833561420563, b=0.06461567440799591, mchange=-0.07037433859056669, bchange=-0.13352860138020378, residual=92.72385850665981
# starting scatter
# starting predictions for epoch 235
# starting residual testing for basic
# Epoch 235: m=1.0894901145069638, b=0.06462901147593356, mchange=-0.06758364907558376, bchange=-0.1333706793764296, residual=92.72372926659878
# starting scatter
# starting predictions for epoch 236
# starting residual testing for basic
# Epoch 236: m=1.0894966038294527, b=0.0646423333184267, mchange=-0.06489322488849723, bchange=-0.13321842493139394, residual=92.7236024175433
# starting scatter
# starting predictions for epoch 237
# starting residual testing for basic
# Epoch 237: m=1.0895028337758184, b=0.06465564048186859, mchange=-0.06229946365785435, bchange=-0.1330716344188644, residual=92.72347779078821
# starting scatter
# starting predictions for epoch 238
# starting residual testing for basic
# Epoch 238: m=1.0895088136650624, b=0.06466893349302144, mchange=-0.059798892439792986, bchange=-0.13293011152858195, residual=92.72335522953297
# starting scatter
# starting predictions for epoch 239
# starting residual testing for basic
# Epoch 239: m=1.0895145524813692, b=0.06468221285972178, mchange=-0.057388163067457254, bchange=-0.13279366700338344, residual=92.72323458804217
# starting scatter
# starting predictions for epoch 240
# starting residual testing for basic
# Epoch 240: m=1.089520058886136, b=0.06469547907156037, mchange=-0.055064047668248635, bchange=-0.13266211838581174, residual=92.7231157308642
# starting scatter
# starting predictions for epoch 241
# starting residual testing for basic
# Epoch 241: m=1.0895253412295702, b=0.06470873260053775, mchange=-0.052823434342038324, bchange=-0.13253528977382387, residual=92.72299853210569
# starting scatter
# starting predictions for epoch 242
# starting residual testing for basic
# Epoch 242: m=1.0895304075618697, b=0.06472197390169628, mchange=-0.05066332299405499, bchange=-0.1324130115852422, residual=92.72288287475706
# starting scatter
# starting predictions for epoch 243
# starting residual testing for basic
# Epoch 243: m=1.0895352656440016, b=0.06473520341372935, mchange=-0.048580821318035046, bchange=-0.13229512033070073, residual=92.72276865006567
# starting scatter
# starting predictions for epoch 244
# starting residual testing for basic
# Epoch 244: m=1.089539922958094, b=0.06474842155956882, mchange=-0.04657314092386306, bchange=-0.13218145839475587, residual=92.72265575695316
# starting scatter
# starting predictions for epoch 245
# starting residual testing for basic
# Epoch 245: m=1.0895443867174543, b=0.06476162874695131, mchange=-0.04463759360362025, bchange=-0.13207187382482394, residual=92.72254410147363
# starting scatter
# starting predictions for epoch 246
# starting residual testing for basic
# Epoch 246: m=1.0895486638762275, b=0.06477482536896408, mchange=-0.04277158773229361, bchange=-0.13196622012772863, residual=92.7224335963108
# starting scatter
# starting predictions for epoch 247
# starting residual testing for basic
# Epoch 247: m=1.0895527611387072, b=0.06478801180457143, mchange=-0.040972624797930984, bchange=-0.13186435607356578, residual=92.72232416030991
# starting scatter
# starting predictions for epoch 248
# starting residual testing for basic
# Epoch 248: m=1.089556684968313, b=0.0648011884191221, mchange=-0.03923829605600796, bchange=-0.13176614550658958, residual=92.72221571804266
# starting scatter
# starting predictions for epoch 249
# starting residual testing for basic
# Epoch 249: m=1.0895604415962434, b=0.06481435556483839, mchange=-0.037566279304162196, bchange=-0.13167145716290243, residual=92.72210819940403
# starting scatter
# starting predictions for epoch 250
# starting residual testing for basic
# Epoch 250: m=1.0895640370298207, b=0.06482751358128785, mchange=-0.03595433577325131, bchange=-0.13158016449472013, residual=92.7220015392353
# starting scatter
# starting predictions for epoch 251
# starting residual testing for basic
# Epoch 251: m=1.0895674770605337, b=0.06484066279583794, mchange=-0.034400307129415525, bchange=-0.13149214550091176, residual=92.72189567697635
# starting scatter
# starting predictions for epoch 252
# starting residual testing for basic
# Epoch 252: m=1.089570767271792, b=0.06485380352409431, mchange=-0.0329021125842575, bchange=-0.13140728256365033, residual=92.7217905563401
# starting scatter
# starting predictions for epoch 253
# starting residual testing for basic
# Epoch 253: m=1.0895739130464028, b=0.0648669360703234, mchange=-0.03145774610868756, bchange=-0.13132546229092462, residual=92.72168612501171
# starting scatter
# starting predictions for epoch 254
# starting residual testing for basic
# Epoch 254: m=1.0895769195737774, b=0.06488006072785987, mchange=-0.03006527374699686, bchange=-0.13124657536471449, residual=92.72158233436784
# starting scatter
# starting predictions for epoch 255
# starting residual testing for basic
# Epoch 255: m=1.0895797918568801, b=0.06489317777949934, mchange=-0.028722831027513013, bchange=-0.13117051639462754, residual=92.72147913921644
# starting scatter
# starting predictions for epoch 256
# starting residual testing for basic
# Epoch 256: m=1.0895825347189267, b=0.06490628749787701, mchange=-0.02742862046580329, bchange=-0.13109718377676546, residual=92.72137649755419
# starting scatter
# starting predictions for epoch 257
# starting residual testing for basic
# Epoch 257: m=1.0895851528098426, b=0.06491939014583278, mchange=-0.026180909158342588, bchange=-0.131026479557705, residual=92.72127437034212
# starting scatter
# starting predictions for epoch 258
# starting residual testing for basic
# Epoch 258: m=1.0895876506124889, b=0.06493248597676311, mchange=-0.024978026461983098, bchange=-0.13095830930332844, residual=92.72117272129584
# starting scatter
# starting predictions for epoch 259
# starting residual testing for basic
# Epoch 259: m=1.0895900324486645, b=0.06494557523496035, mchange=-0.023818361757027635, bchange=-0.13089258197238032, residual=92.72107151669145
# starting scatter
# starting predictions for epoch 260
# starting residual testing for basic
# Epoch 260: m=1.0895923024848935, b=0.0649586581559398, mchange=-0.02270036229084164, bchange=-0.13082920979457574, residual=92.720970725185
# starting scatter
# starting predictions for epoch 261
# starting residual testing for basic
# Epoch 261: m=1.0895944647380034, b=0.06497173496675511, mchange=-0.02162253109866852, bchange=-0.13076810815307338, residual=92.72087031764403
# starting scatter
# starting predictions for epoch 262
# starting residual testing for basic
# Epoch 262: m=1.0895965230805034, b=0.06498480588630223, mchange=-0.02058342499919207, bchange=-0.1307091954711736, residual=92.72077026699205
# starting scatter
# starting predictions for epoch 263
# starting residual testing for basic
# Epoch 263: m=1.0895984812457695, b=0.06499787112561255, mchange=-0.019581652662315974, bchange=-0.1306523931030988, residual=92.72067054806323
# starting scatter
# starting predictions for epoch 264
# starting residual testing for basic
# Epoch 264: m=1.089600342833044, b=0.06501093088813542, mchange=-0.018615872746223477, bchange=-0.13059762522868884, residual=92.7205711374676
# starting scatter
# starting predictions for epoch 265
# starting residual testing for basic
# Epoch 265: m=1.0896021113122543, b=0.06502398537001061, mchange=-0.017684792101347244, bchange=-0.13054481875187954, residual=92.72047201346555
# starting scatter
# starting predictions for epoch 266
# starting residual testing for basic
# Epoch 266: m=1.0896037900286581, b=0.06503703476033089, mchange=-0.016787164038834033, bchange=-0.130493903202827, residual=92.72037315585173
# starting scatter
# starting predictions for epoch 267
# starting residual testing for basic
# Epoch 267: m=1.0896053822073244, b=0.06505007924139525, mchange=-0.015921786661425484, bchange=-0.1304448106435598, residual=92.72027454584665
# starting scatter
# starting predictions for epoch 268
# starting residual testing for basic
# Epoch 268: m=1.08960689095745, b=0.06506311898895295, mchange=-0.015087501253965116, bchange=-0.1303974755770002, residual=92.72017616599585
# starting scatter
# starting predictions for epoch 269
# starting residual testing for basic
# Epoch 269: m=1.0896083192765231, b=0.06507615417243888, mchange=-0.014283190732238668, bchange=-0.13035183485928545, residual=92.72007800007665
# starting scatter
# starting predictions for epoch 270
# starting residual testing for basic
# Epoch 270: m=1.0896096700543378, b=0.0650891849552004, mchange=-0.01350777814698645, bchange=-0.13030782761520499, residual=92.71998003301098
# starting scatter
# starting predictions for epoch 271
# starting residual testing for basic
# Epoch 271: m=1.089610946076862, b=0.06510221149471607, mchange=-0.012760225241889524, bchange=-0.1302653951566907, residual=92.71988225078505
# starting scatter
# starting predictions for epoch 272
# starting residual testing for basic
# Epoch 272: m=1.0896121500299683, b=0.0651152339428065, mchange=-0.012039531063845843, bchange=-0.1302244809042607, residual=92.71978464037377
# starting scatter
# starting predictions for epoch 273
# starting residual testing for basic
# Epoch 273: m=1.0896132845030304, b=0.06512825244583761, mchange=-0.01134473062186097, bchange=-0.1301850303112139, residual=92.71968718967125
# starting scatter
# starting predictions for epoch 274
# starting residual testing for basic
# Epoch 274: m=1.08961435199239, b=0.06514126714491668, mchange=-0.010674893595857307, bchange=-0.1301469907906433, residual=92.71958988742576
# starting scatter
# starting predictions for epoch 275
# starting residual testing for basic
# Epoch 275: m=1.089615354904699, b=0.06515427817608117, mchange=-0.01002912309065638, bchange=-0.13011031164500458, residual=92.71949272317968
# starting scatter
# starting predictions for epoch 276
# starting residual testing for basic
# Epoch 276: m=1.0896162955601425, b=0.065167285670481, mchange=-0.009406554434992075, bchange=-0.13007494399822986, residual=92.71939568721334
# starting scatter
# starting predictions for epoch 277
# starting residual testing for basic
# Epoch 277: m=1.0896171761955449, b=0.06518028975455402, mchange=-0.008806354023781231, bchange=-0.13004084073028596, residual=92.71929877049276
# starting scatter
# starting predictions for epoch 278
# starting residual testing for basic
# Epoch 278: m=1.089617998967365, b=0.06519329055019543, mchange=-0.0082277182021168, bchange=-0.13000795641409188, residual=92.71920196462185
# starting scatter
# starting predictions for epoch 279
# starting residual testing for basic
# Epoch 279: m=1.089618765954584, b=0.0652062881749209, mchange=-0.007669872189176542, bchange=-0.12997624725469117, residual=92.71910526179647
# starting scatter
# starting predictions for epoch 280
# starting residual testing for basic
# Epoch 280: m=1.089619479161488, b=0.06521928274202396, mchange=-0.007132069040631693, bchange=-0.12994567103060262, residual=92.71900865476356
# Best model: LSQ with residual squared: 92.71900865476356
# 1.089619479161488 0.06521928274202396 92.71900865476356 Equation: y predicted = 1.089619479161488x+0.06521928274202396

# %%
def predictions(m=m, b=b):
    x=int(input('what x value?'))
    x=np.log(x)

    y=(m*x)+b
    y = np.exp(y)
    return y

# %%
predictions()
# Out:
# what x value?5000000
# 21264372.999669887
